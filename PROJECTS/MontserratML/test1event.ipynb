# %%
import os, sys
LIBpath = os.path.join( os.getenv('HOME'),'src','kitchensinkGT', 'LIB')
sys.path.append(LIBpath)
from libSeisan2Pandas import process1event, set_globals
SEISAN_DATA, SEISAN_DB, station_locationsDF, MASTER_INV, bool_detect_event, bool_overwrite = set_globals()
sfilebase = '04-0556-28L.S199703'
sfilebase = '06-2328-06L.S200004'
sfilebase = '01-2108-29L.S200601'
sfilebase = '01-0954-24L.S200601'
sfile=os.path.join(SEISAN_DATA,'REA',SEISAN_DB,sfilebase[-6:-2],sfilebase[-2:],sfilebase)
bool_overwrite=True
process1event(sfile, bool_overwrite, station_locationsDF=station_locationsDF, MASTER_INV=MASTER_INV)
# Out:
# Parsing  /Users/gt/DATA/MVO/REA/MVOE_/2006/01/01-0954-24L.S200601
# .MBHA..BZ -> MV.MBHA..HHZ
# .MBHA..BZ -> MV.MBHA..HHZ
# .MBLG..BZ -> MV.MBLG..HHZ
# .MBLG..BZ -> MV.MBLG..HHZ
# .MBFL..SZ -> MV.MBFL..EHZ
# .MBFL..SZ -> MV.MBFL..EHZ
# .MBRY..BZ -> MV.MBRY..HHZ
# .MBRY..BZ -> MV.MBRY..HHZ
# .MBGH..BZ -> MV.MBGH..HHZ
# .MBGH..BZ -> MV.MBGH..HHZ
# .MBFR..BZ -> MV.MBFR..HHZ
# .MBFR..BZ -> MV.MBFR..HHZ
# .MBGB..BZ -> MV.MBGB..HHZ
# .MBGB..BZ -> MV.MBGB..HHZ
# .MBWH..BH -> MV.MBWH..HH
# .MBWH..BH -> MV.MBWH..HH
# .MBWH..BH -> MV.MBWH..HH
# .MBRY..BHZ -> MV.MBRY..HHZ
# .MBRY..BHN -> MV.MBRY..HHN
# .MBRY..BHE -> MV.MBRY..HHE
# .MBRV..SH -> MV.MBRV..EH
# .MBLG..BHZ -> MV.MBLG..HHZ
# .MBLG..BHN -> MV.MBLG..HHN
# .MBLG..BHE -> MV.MBLG..HHE
# .MBHA..BHZ -> MV.MBHA..HHZ
# .MBHA..BHN -> MV.MBHA..HHN
# .MBHA..BHE -> MV.MBHA..HHE
# .MBGH..BHZ -> MV.MBGH..HHZ
# .MBGH..BHN -> MV.MBGH..HHN
# .MBGH..BHE -> MV.MBGH..HHE
# .MBGB..BHZ -> MV.MBGB..HHZ
# .MBGB..BHN -> MV.MBGB..HHN
# .MBGB..BHE -> MV.MBGB..HHE
# .MBFR..BHZ -> MV.MBFR..HHZ
# .MBFR..BHN -> MV.MBFR..HHN
# .MBFR..BHE -> MV.MBFR..HHE
# .MBFL..SHZ -> MV.MBFL..EHZ
# .MBBY..BH -> MV.MBBY..HH
# .MBBY..BH -> MV.MBBY..HH
# .MBBY..BH -> MV.MBBY..HH
# Loading /Users/gt/DATA/MVO/WAV/MVOE_/2006/01/2006-01-01-0954-24S.MVO___026
# .MBBY.Z.BH -> MV.MBBY..MHZ
# .MBBY.N.BH -> MV.MBBY..MHN
# .MBBY.E.BH -> MV.MBBY..MHE
# .MBFL.Z.SH -> MV.MBFL..EHZ
# .MBFR.Z.BH -> MV.MBFR..HHZ
# .MBFR.N.BH -> MV.MBFR..HHN
# .MBFR.E.BH -> MV.MBFR..HHE
# .MBGB.Z.BH -> MV.MBGB..HHZ
# .MBGB.N.BH -> MV.MBGB..HHN
# .MBGB.E.BH -> MV.MBGB..HHE
# .MBGH.Z.BH -> MV.MBGH..HHZ
# .MBGH.N.BH -> MV.MBGH..HHN
# .MBGH.E.BH -> MV.MBGH..HHE
# .MBHA.Z.BH -> MV.MBHA..HHZ
# .MBHA.N.BH -> MV.MBHA..HHN
# .MBHA.E.BH -> MV.MBHA..HHE
# .MBLG.Z.BH -> MV.MBLG..HHZ
# .MBLG.N.BH -> MV.MBLG..HHN
# .MBLG.E.BH -> MV.MBLG..HHE
# .MBRV.Z.SH -> MV.MBRV..MHZ
# .MBRY.Z.BH -> MV.MBRY..HHZ
# .MBRY.N.BH -> MV.MBRY..HHN
# .MBRY.E.BH -> MV.MBRY..HHE
# .MBWH.Z.BH -> MV.MBWH..MHZ
# .MBWH.N.BH -> MV.MBWH..MHN
# .MBWH.E.BH -> MV.MBWH..MHE
# Creating /Users/gt/DATA/MVO/miniseed_c/MVOE_/2006/01/2006-01-01-0954-24S.MVO___026.mseed
# /Users/gt/DATA/MVO/WAV/MVOE_/2006/01/2006-01-01-0954-24S.MVO___026: poor trace MV.MBBY..MHZ
# /Users/gt/DATA/MVO/WAV/MVOE_/2006/01/2006-01-01-0954-24S.MVO___026: poor trace MV.MBBY..MHN
# /Users/gt/DATA/MVO/WAV/MVOE_/2006/01/2006-01-01-0954-24S.MVO___026: poor trace MV.MBBY..MHE
# /Users/gt/DATA/MVO/WAV/MVOE_/2006/01/2006-01-01-0954-24S.MVO___026: poor trace MV.MBRV..MHZ
# /Users/gt/DATA/MVO/WAV/MVOE_/2006/01/2006-01-01-0954-24S.MVO___026: poor trace MV.MBWH..MHZ
# /Users/gt/DATA/MVO/WAV/MVOE_/2006/01/2006-01-01-0954-24S.MVO___026: poor trace MV.MBWH..MHN
# /Users/gt/DATA/MVO/WAV/MVOE_/2006/01/2006-01-01-0954-24S.MVO___026: poor trace MV.MBWH..MHE
# Creating /Users/gt/DATA/MVO/miniseed_c/MVOE_/2006/01/2006-01-01-0954-24S.MVO___026.csv
#               id                    starttime     Fs         calib units  \
# 0   MV.MBFL..EHZ  2006-01-01T09:54:24.000000Z  100.0  3.630728e+08   m/s
# 1   MV.MBFR..HHZ  2006-01-01T09:54:24.000000Z  100.0  6.371640e+08   m/s
# 2   MV.MBFR..HHN  2006-01-01T09:54:24.000000Z  100.0  6.371640e+08   m/s
# 3   MV.MBFR..HHE  2006-01-01T09:54:24.000000Z  100.0  6.371640e+08   m/s
# 4   MV.MBGB..HHZ  2006-01-01T09:54:24.000000Z  100.0  6.371640e+08   m/s
# 2                  -3.186435                 -1.002445 -62.185556  16.699444
# 3                  -3.120676                 -1.186574 -62.185556  16.699444
# 4                  -3.268843                 -0.466259 -62.235000  16.728333
# 5                  -4.329458                 -1.836080 -62.235000  16.728333
# 6                  -4.128565                 -2.012646 -62.235000  16.728333
# 7                  -2.945256                 -0.882296 -62.205000  16.731667
# 8                  -3.939050                 -2.139293 -62.205000  16.731667
# 9                  -3.750985                 -1.941431 -62.205000  16.731667
# 10                 -2.236155                 -1.023552 -62.174444  16.744167
# 11                 -3.237894                 -1.577425 -62.174444  16.744167
# 12                 -3.115835                 -1.719168 -62.174444  16.744167
# 13                 -2.473933                 -0.681906 -62.159722  16.716667
# 14                 -2.661387                 -1.233471 -62.159722  16.716667
# 15                 -2.670625                 -1.081835 -62.159722  16.716667
# 16                 -1.653597                 -0.070622 -62.175000  16.709444
# 17                 -2.061954                 -0.566878 -62.175000  16.709444
# 18                 -2.079694                 -0.659904 -62.175000  16.709444
#
#      elev            R      magA       Eseismic      magE
# 0   243.0  6140.181086  0.541565   20634.200155 -0.823608
# 1   541.0  1929.285819  0.010781    4656.151661 -1.254649
# 2   541.0  1929.285819  0.540025   41316.451952 -0.622585
# 3   541.0  1929.285819  0.454553   41345.257836 -0.622383
# 4   253.0  5653.124630  0.693309   27574.891121 -0.739657
# 5   253.0  5653.124630  1.033004  130231.371262 -0.290190
# 6   253.0  5653.124630  1.135966  156102.479268 -0.237727
# 7   350.0  2847.297290  0.964032  224772.436262 -0.132171
# 8   350.0  2847.297290  1.293623  950717.188375  0.285368
# 9   350.0  2847.297290  1.235611  962845.704998  0.289038
# 10  291.0  3201.294843  0.109772   10198.190032 -1.027651
# 11  291.0  3201.294843  0.525813   39686.430450 -0.634239
# 12  291.0  3201.294843  0.380585   24576.098418 -0.772991
# 13  287.0  2514.403812 -0.261246    2019.248722 -1.496540
# 14  287.0  2514.403812 -0.072654    4322.217000 -1.276196
# 15  287.0  2514.403812 -0.335210     988.641516 -1.703307
# 16  355.0  1196.620503 -0.787933     394.684408 -1.969167
# 17  355.0  1196.620503 -0.429127    2055.562179 -1.491380
# 18  355.0  1196.620503 -0.431451    1515.772431 -1.579577
#
# [19 rows x 38 columns]
# {'sfile': '01-0954-24L.S200601',
#  'DSN_wavfile': '2006-01-01-0954-24S.MVO___026',
#  'DSN_exists': True,
#  'ASN_wavfile': None,
#  'ASN_exists': False,
#  'corrected_DSN_mseed': '/Users/gt/DATA/MVO/miniseed_c/MVOE_/2006/01/2006-01-01-0954-24S.MVO___026.mseed',
#  'corrected_ASN_mseed': None,
#  'mainclass': 'LV',
#  'subclass': 'r'}

# %%
import obspy
#st = obspy.read('/Users/gt/DATA/MVO/WAV/MVOE_/2006/01/2006-01-01-2108-29S.MVO___026')
st = obspy.read('/Users/gt/DATA/MVO/WAV/MVOE_/2006/01/2006-01-01-0954-24S.MVO___026')
st.plot(equal_scale=False)
