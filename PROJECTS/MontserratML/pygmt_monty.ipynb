# %%
#import pygmt

# %%
import cartopy.crs as ccrs
import cartopy
import cartopy.feature as cf
import numpy as np
import matplotlib.pyplot as plt

# %%
central_lat = 37.5
central_lon = -96
extent = [-120, -70, 24, 50.5]
central_lon = np.mean(extent[:2])
central_lat = np.mean(extent[2:])

plt.figure(figsize=(12, 6))
ax = plt.axes(projection=ccrs.AlbersEqualArea(central_lon, central_lat))
ax.set_extent(extent)

ax.add_feature(cartopy.feature.OCEAN)
ax.add_feature(cartopy.feature.LAND, edgecolor='black')
ax.add_feature(cartopy.feature.LAKES, edgecolor='black')
ax.add_feature(cartopy.feature.RIVERS)
ax.gridlines()

# %%
extent = [-65, -60, 16, 17]
central_lon = np.mean(extent[:2])
central_lat = np.mean(extent[2:])

plt.figure(figsize=(12, 6))
ax = plt.axes(projection=ccrs.AlbersEqualArea(central_lon, central_lat))
ax.set_extent(extent)

ax.add_feature(cartopy.feature.OCEAN)
ax.add_feature(cartopy.feature.LAND, edgecolor='black')
ax.add_feature(cartopy.feature.LAKES, edgecolor='black')
ax.add_feature(cartopy.feature.RIVERS)
ax.gridlines()

# %%
extent = [-62.8, -62.2, 16.5, 17]
central_lon = np.mean(extent[:2])
central_lat = np.mean(extent[2:])

plt.figure(figsize=(12, 6))
ax = plt.axes(projection=ccrs.AlbersEqualArea(central_lon, central_lat))
ax.set_extent(extent)

ax.add_feature(cartopy.feature.OCEAN)
#ax.add_feature(cartopy.feature.LAND, edgecolor='black')
#ax.add_feature(cartopy.feature.LAKES, edgecolor='black')
#ax.add_feature(cartopy.feature.RIVERS)
ax.gridlines()

# %%
extent = [-62.3, -62.1, 16.65, 16.85]
central_lon = np.mean(extent[:2])
central_lat = np.mean(extent[2:])

plt.figure(figsize=(12, 6))
#ax = plt.axes(projection=ccrs.AlbersEqualArea(central_lon, central_lat))
inclination = 50  # degrees from pole
ax = plt.axes(projection=ccrs.Orthographic(central_lon,
                                  central_lat))
ax.set_extent(extent)
ax.add_feature(cf.COASTLINE)
#ax.add_feature(cf.OCEAN)
#ax.add_feature(cf.LAND, edgecolor='black')
#ax.add_feature(cf.LAKES, edgecolor='black')
#ax.add_feature(cf.RIVERS)
ax.gridlines()

# %%
import cartopy.crs as ccrs
#import cartopy
import cartopy.feature as cf
import numpy as np
import matplotlib.pyplot as plt
extent = [-62.27, -62.12, 16.67, 16.82]
central_lon = np.mean(extent[:2])
central_lat = np.mean(extent[2:])

plt.figure(figsize=(12, 6))
#ax = plt.axes(projection=ccrs.AlbersEqualArea(central_lon, central_lat))
inclination = 50  # degrees from pole
ortho = ccrs.Orthographic(central_lon, central_lat)
geo = ccrs.Geodetic()
ax = plt.axes(projection=ortho)
ax.set_extent(extent)
ax.add_feature(cf.COASTLINE)
ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False)

lons = np.array([-62.18805555555555, -62.18805555555555, -62.18805555555555, -62.159722222222221, -62.174999999999997, -62.174999999999997, -62.189999999999998, -62.189999999999998, -62.189999999999998, -62.205000000000005, -62.205000000000005, -62.205000000000005, -62.198888888888888, -62.198888888888888, -62.152499999999996, -62.152499999999996, -62.152499999999996, -62.234999999999999, -62.234999999999999, -62.234999999999999] )
lats = np.array([16.703055555555554, 16.703055555555554, 16.703055555555554, 16.716666666666665, 16.709444444444443, 16.709444444444443, 16.684444444444445, 16.684444444444445, 16.684444444444445, 16.731666666666666, 16.731666666666666, 16.731666666666666, 16.741944444444446, 16.741944444444446, 16.736944444444447, 16.736944444444447, 16.736944444444447, 16.728333333333332, 16.728333333333332, 16.728333333333332])
points = ortho.transform_points(geo, lons, lats)
ax.plot(points[:, 0], points[:, 1], 'ro')
textlabels = [{'lon': -62.18805555555555, 'lat': 16.703055555555554, 'label': 'MBGA'}, {'lon': -62.159722222222221, 'lat': 16.716666666666665, 'label': 'MBLG'}, {'lon': -62.174999999999997, 'lat': 16.709444444444443, 'label': 'MBRY'}, {'lon': -62.189999999999998, 'lat': 16.684444444444445, 'label': 'MBGE'}, {'lon': -62.205000000000005, 'lat': 16.731666666666666, 'label': 'MBGH'}, {'lon': -62.198888888888888, 'lat': 16.741944444444446, 'label': 'MBWH'}, {'lon': -62.152499999999996, 'lat': 16.736944444444447, 'label': 'MBBE'}, {'lon': -62.234999999999999, 'lat': 16.728333333333332, 'label': 'MBGB'}]
for thislabel in textlabels:
    thispoint = ortho.transform_points(geo, np.array(thislabel['lon']), np.array(thislabel['lat']))
    ax.text(thispoint[0,0], thispoint[0,1], thislabel['label'])
#g=ax.scatter(lons,lats,s=30,c='green',marker='o')
#g.set_facecolor('none')
#g.set_edgecolor('blue')

plt.show()

# %%
import cartopy.crs as ccrs
#import cartopy
import cartopy.feature as cf
import numpy as np
import matplotlib.pyplot as plt
extent = [-62.27, -62.12, 16.67, 16.82]
central_lon = np.mean(extent[:2])
central_lat = np.mean(extent[2:])

plt.figure(figsize=(12, 6))
#ax = plt.axes(projection=ccrs.AlbersEqualArea(central_lon, central_lat))
inclination = 50  # degrees from pole
#ortho = ccrs.Orthographic(central_lon, central_lat)
#geo = ccrs.Geodetic()
ax = plt.axes(projection==crs.PlateCarree())
ax.set_extent(extent, crs==crs.PlateCarree())
ax.add_feature(cf.COASTLINE)
ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False)

lons = np.array([-62.18805555555555, -62.18805555555555, -62.18805555555555, -62.159722222222221, -62.174999999999997, -62.174999999999997, -62.189999999999998, -62.189999999999998, -62.189999999999998, -62.205000000000005, -62.205000000000005, -62.205000000000005, -62.198888888888888, -62.198888888888888, -62.152499999999996, -62.152499999999996, -62.152499999999996, -62.234999999999999, -62.234999999999999, -62.234999999999999] )
lats = np.array([16.703055555555554, 16.703055555555554, 16.703055555555554, 16.716666666666665, 16.709444444444443, 16.709444444444443, 16.684444444444445, 16.684444444444445, 16.684444444444445, 16.731666666666666, 16.731666666666666, 16.731666666666666, 16.741944444444446, 16.741944444444446, 16.736944444444447, 16.736944444444447, 16.736944444444447, 16.728333333333332, 16.728333333333332, 16.728333333333332])
#points = ortho.transform_points(geo, lons, lats)
#ax.plot(points[:, 0], points[:, 1], 'ro')
ax.scatter(x=lons, y=lats,
            color="orangered",
            s=30,
            alpha=0.8,
            transform=crs.PlateCarree())
textlabels = [{'lon': -62.18805555555555, 'lat': 16.703055555555554, 'label': 'MBGA'}, {'lon': -62.159722222222221, 'lat': 16.716666666666665, 'label': 'MBLG'}, {'lon': -62.174999999999997, 'lat': 16.709444444444443, 'label': 'MBRY'}, {'lon': -62.189999999999998, 'lat': 16.684444444444445, 'label': 'MBGE'}, {'lon': -62.205000000000005, 'lat': 16.731666666666666, 'label': 'MBGH'}, {'lon': -62.198888888888888, 'lat': 16.741944444444446, 'label': 'MBWH'}, {'lon': -62.152499999999996, 'lat': 16.736944444444447, 'label': 'MBBE'}, {'lon': -62.234999999999999, 'lat': 16.728333333333332, 'label': 'MBGB'}]
for thislabel in textlabels:
    #thispoint = ortho.transform_points(geo, np.array(thislabel['lon']), np.array(thislabel['lat']))
    #ax.text(thispoint[0,0], thispoint[0,1], thislabel['label'])
    ax.text(np.array(thislabel['lon']), np.array(thislabel['lat']),
            thislabel['label'],
            transform=crs.PlateCarree())
#g=ax.scatter(lons,lats,s=30,c='green',marker='o')
#g.set_facecolor('none')
#g.set_edgecolor('blue')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-17c8b03b9a08> in <module>
#      13 #ortho = ccrs.Orthographic(central_lon, central_lat)
#      14 #geo = ccrs.Geodetic()
# ---> 15 ax = plt.axes(projection==crs.PlateCarree())
#      16 ax.set_extent(extent, crs==crs.PlateCarree())
#      17 ax.add_feature(cf.COASTLINE)
#
# NameError: name 'projection' is not defined

# %%
import cartopy.crs as crs
import cartopy.feature as cfeature
extent = [-62.27, -62.12, 16.67, 16.82]
#central_lon = np.mean(extent[:2])
#central_lat = np.mean(extent[2:])
fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(1,1,1, projection=crs.PlateCarree())
ax.set_extent(extent, crs=crs.PlateCarree())

ax.add_feature(cfeature.COASTLINE)
ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False)
lons = np.array([-62.18805555555555, -62.18805555555555, -62.18805555555555, -62.159722222222221, -62.174999999999997, -62.174999999999997, -62.189999999999998, -62.189999999999998, -62.189999999999998, -62.205000000000005, -62.205000000000005, -62.205000000000005, -62.198888888888888, -62.198888888888888, -62.152499999999996, -62.152499999999996, -62.152499999999996, -62.234999999999999, -62.234999999999999, -62.234999999999999] )
lats = np.array([16.703055555555554, 16.703055555555554, 16.703055555555554, 16.716666666666665, 16.709444444444443, 16.709444444444443, 16.684444444444445, 16.684444444444445, 16.684444444444445, 16.731666666666666, 16.731666666666666, 16.731666666666666, 16.741944444444446, 16.741944444444446, 16.736944444444447, 16.736944444444447, 16.736944444444447, 16.728333333333332, 16.728333333333332, 16.728333333333332])
ax.scatter(x=lons, y=lats,
            color="orangered",
            s=30,
            alpha=0.8,
            transform=crs.PlateCarree())
textlabels = [{'lon': -62.18805555555555, 'lat': 16.703055555555554, 'label': 'MBGA'}, {'lon': -62.159722222222221, 'lat': 16.716666666666665, 'label': 'MBLG'}, {'lon': -62.174999999999997, 'lat': 16.709444444444443, 'label': 'MBRY'}, {'lon': -62.189999999999998, 'lat': 16.684444444444445, 'label': 'MBGE'}, {'lon': -62.205000000000005, 'lat': 16.731666666666666, 'label': 'MBGH'}, {'lon': -62.198888888888888, 'lat': 16.741944444444446, 'label': 'MBWH'}, {'lon': -62.152499999999996, 'lat': 16.736944444444447, 'label': 'MBBE'}, {'lon': -62.234999999999999, 'lat': 16.728333333333332, 'label': 'MBGB'}]
for thislabel in textlabels:
    ax.text(np.array(thislabel['lon']), np.array(thislabel['lat']),
            thislabel['label'],
            transform=crs.PlateCarree())
plt.show()
