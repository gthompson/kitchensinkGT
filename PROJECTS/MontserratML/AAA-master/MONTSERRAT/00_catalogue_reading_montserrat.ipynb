# %% [markdown]
# # Reading Montserrat CSV catalog into DataFrame
# ---
#
# **Last update:** 07/2021 - Glenn THOMPSON
# **Contact:** thompsong@usf.edu
# ---

# %%
import os
import pandas as pd
import pickle
import numpy as np


# Change if you want your screen to keep quiet
# 0 = quiet
# 1 = in between
# 2 = detailed information
verbatim = 2

### PREPARE THE CATALOG DataFrame ###

PROJECTDIR = os.path.join(os.getenv('HOME'),'src', 'kitchensinkGT', 'PROJECTS', 'MontserratML')
csvfile_external = os.path.join(PROJECTDIR, 'MVO_labelled_events.csv')
csvfile_internal = './catalog/MVO_labelled_events_filtered.csv'

# copy the catalog CSV file from external to internal directory
os.system('cp %s %s' % (csvfile_external, csvfile_internal))

# read the catalog
cat = pd.read_csv(csvfile_external)

# count by (sub)class
print('%d events before filtering' % len(cat.index))
cat['class'].value_counts()

# fix f0 and f1 columns - not really sure what this does
#cat['f0'] = cat.apply(lambda x:eval(x['f0']), axis=1)
#cat['f1'] = cat.apply(lambda x:eval(x['f1']), axis=1)
cat['f0']=None
cat['f1']=None

# List of traceID occurrences
frames = []
for i,row in cat.iterrows():
    
    # change WAV path to picklepath
    picklepath = row['path'].replace('./WAV','eventFiles')+'.pickle'
    if not os.path.exists(picklepath):
        print('file not found :', picklefile)
        break
    cat.loc[i, 'path'] = picklepath
    
    # load trace CSV file
    tracecsv = picklepath.replace('.pickle','.csv')
    tracedf = pd.read_csv(tracecsv)
    tracedf['filetime'] = row['filetime']
    frames.append(tracedf)

# stitch all the trace CSV files together    
alltraces = pd.concat(frames, sort=True)
alltraces.to_csv('alltraceDFs.csv')

#alltraces.set_index('filetime', inplace=True) # we will need this later to remerge
#alltraces.sort_index(inplace=True)
print(alltraces['id'].value_counts())

# save the catalog to CSV and pickle file
cat.to_csv(csvfile_internal)
output_path_cat = csvfile_internal.replace('.csv', '.pd')
pickle.dump(cat, open(output_path_cat,'wb'))
# Out:
# 522 events before filtering
# MV.MBWH..SHZ     517
# MV.MBLG..SHZ     474
# MV.MBRY..SHZ     452
# MV.MBGB..SHN     441
# MV.MBGB..SHZ     436
# MV.MBGB..SHE     432
# MV.MBGH..SHZ     431
# MV.MBGH..SHE     429
# MV.MBGH..SHN     423
# MV.MBGA..SHE     338
# MV.MBGA..SHZ     337
# MV.MBGA..SHN     335
# MV.MBGE..SHN     334
# MV.MBGE..SHE     333
# MV.MBGE..SHZ     333
# MV.MBBE..SHE     328
# MV.MBBE..SHZ     326
# MV.MBBE..SHN     325
# MV.MBSS..SHZ     143
# MV.MBRY..BHN     142
# MV.MBRY..SHN     118
# MV.MBRY..SHE     116
# MV.MBMH..SHZ     114
# MV.MBWH..BHN     103
# MV.MBLG..BHN      97
# MV.MBBY..SHZ      60
# MV.MBBY..SHE      57
# MV.MBBY..SHN      56
# MV.MBMH..SHN      48
# MV.MBRY..BHZ      44
# MV.MBRY..BHE      44
# MV.MBGB..BHN      43
# MV.MBGB..BHZ      43
# MV.MBGB..BHE      43
# MV.MBLG.E.BDF     38
# MV.MBMH..SHE      34
# MV.MBGH..BHE      26
# MV.MBGH..BHN      26
# MV.MBGH..BHZ      26
# MV.MBLG.S.BDF     18
# MV.MBUN..SHZ       5
# Name: id, dtype: int64

# %%
################################
# Machine learning and testing #
################################
import sys
sys.path.insert(0, '../automatic_processing')
#import tools
from config import Config
from analyzer import Analyzer

# Change if you want your screen to keep quiet
# 0 = quiet
# 1 = in between
# 2 = detailed information
verbatim = 2

# Init project with configuration file
config = Config('../config/general/newsettings_10.json', verbatim=verbatim)
config.readAndCheck()  

##########################
# Variables to loop over #
##########################

traceIDs = ['MV.MBWH..SHZ', 'MV.MBLG..SHZ', 'MV.MBRY..SHZ']
minWeights = range(4)
classes_to_include = [ ['l', 't'], ['e', 'r'], ['h', 'l', 't'], ['h', 'l', 't', 'r'], ['e', 'h', 'l', 't', 'r'] ]
"""
traceIDs = ['MV.MBWH..SHZ']
minWeights = range(1)
classes_to_include = [ ['e', 'h', 'l', 't', 'r'] ]
"""

#############
# Functions #
#############

def cat_filter_traceID(cat, alltraces, traceID):
    # subset catalog based on traceID
    matchingEvents = alltraces[alltraces['id']==traceID]
    for i, row in cat.iterrows():
        matching_indices = matchingEvents.index[matchingEvents['filetime']==row['filetime']].tolist()
        if len(matching_indices)==1:
            pass
        else:
            cat.drop(i, inplace=True)
    N = len(cat.index)
    #print('%d events after matching against traceID' % N)
    return N

def cat_filter_classes(cat, remove_classes):
    """
    for rmclass in remove_classes:
        print('Removing %s' % rmclass)
        cat = cat[cat['class']!=rmclass]
    """
    cat=cat[cat["class"].isin(remove_classes)]
    N = len(cat.index)
    #print('%d events after removing classes' % N)
    return cat, N

def cat_filter_weight(cat, minWeight):
    #if minWeight>0:
    #    cat = cat[cat['weight']>=minWeight]
    cat=cat[cat["weight"].isin(range(minWeight,13))]
    N = len(cat.index)
    #print('%d events after filtering above %d' % (N, minWeight))
    return cat, N

def cat_check_numbers(cat, minthresh = 20):
    df = cat.copy()
    tooSmall = False
    lengths = []
    for subclass in df['class'].unique():
        dfs = df[df['class']==subclass]
        N = len(dfs.index)
        if N<minthresh:
            tooSmall=True
        lengths.append(N)
    return tooSmall, lengths


#######################
# Looping starts here #
#######################
minPerClass = 30
counter = 0
results_list = []
for traceID in traceIDs:
    
    # what traceID are we looking for - read_montserrat needs this - should figure out how to write this into the config
    fptr = open('current_traceID.txt','w')
    fptr.write(traceID)
    fptr.close()
    
    for minWeight in minWeights:
        for include_classes in classes_to_include:
            # reload cat because we filter it down each time
            cat = pickle.load(open(output_path_cat,'rb'))
            #print(cat['class'].value_counts())
            print(traceID, include_classes, minWeight)
            
            results_dict = {}
            results_dict['traceID'] = traceID
            results_dict['classes'] = ','.join(include_classes)
            results_dict['minWeight'] = minWeight
            results_dict['NtraceID'] = cat_filter_traceID(cat, alltraces, traceID)
            cat, N = cat_filter_classes(cat, include_classes) 
            results_dict['Nclasses'] = N
            cat, N = cat_filter_weight(cat, minWeight)
            results_dict['Nweight'] = N
            tooSmall, lengths = cat_check_numbers(cat, minPerClass)
            results_dict['counts'] = str(lengths)
            
            results_dict['acc_mean'] = None
            results_dict['acc_std'] = None
            
            if N>=minPerClass*len(include_classes) and not tooSmall:
                #try:
                    print(cat.groupby('class').size())
                    analyzer = Analyzer(config, verbatim=verbatim, catalog=cat)
                    allData, allLabels, acc = analyzer.learn(config, returnData=True) # If you want the data
                    results_dict['acc_mean'] = np.round(np.mean(acc)*100, 1)
                    results_dict['acc_std'] = np.round(np.std(acc)*100, 1)                        
                    cat['predicted_class'] = allLabels
                    cat.to_csv(csvfile_internal.replace('.csv','_predicted_%d.csv' % counter)) 
            results_list.append(results_dict)
            counter += 1
            
resultsDF = pd.DataFrame(results_list)
resultsDF.to_csv('results.csv')
print('Done')
# Out:
# /Users/thompsong/miniconda3/envs/AAA/lib/python3.8/site-packages/obspy/clients/arclink/__init__.py:178: ObsPyDeprecationWarning: The ArcLink protocol will be deprecated in the near future. Please, use the client contacting the routing service provided by EIDA: https://docs.obspy.org/packages/obspy.clients.fdsn.html#basic-routing-clients-usage
#   warnings.warn(msg, category=ObsPyDeprecationWarning)
# /Users/thompsong/src/AAA-master/config/specific/usecase1_continuous_classification/usecase1_EXAMPLE.json
# Welcome to this automatic analysis architecture
# Copyright: Marielle MALFANTE - GIPSA-Lab
# Univ. Grenoble Alpes, CNRS, Grenoble INP, GIPSA-lab, 38000 Grenoble, France
#
#  *** PROJECT CONFIGURATION 10 ***
# Configuration object from <path> ../config/general/newsettings_10.json, <configuration_number> 10,
#  <general> {'project_root': '/Users/thompsong/src/AAA-master/', 'analysis_type': 'continuous', 'path_to_specific_settings_file': 'config/specific/usecase1_continuous_classification/usecase1_EXAMPLE.json', 'path_to_res': 'res/', 'path_to_visuals': 'fig/', 'path_to_res_to_review': 'res_to_review/'},
#  <application> {'name': 'montserrat'},
#  <preprocessing> {'energy_norm': True},
#  <learning> {'algo': RandomForestClassifier(criterion='entropy'), 'cv': StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5), 'path_to_catalogue': 'catalog/MVO_labelled_events_filtered.pd'},
#  <features> {'path_to_config': 'config/specific/features/features_montserrat.json', 'computation_domains': 'time spectral cepstral', 'thresholding': True, 'thresholds': [0.8, 0.8, 0.8, 0.8, 0.8]},
#  <data_to_analyze> {'path_to_data': '/Users/thompsong/Dropbox/MVO_labelled_events/', 'data_files': '*.pickle', 'reading_function': <function read_montserrat at 0x7f8c6a1e4a60>, 'reading_arguments': {}},
#  <analysis> {'n_window': 1, 'window_length': 15.0, 'delta': 100, 'bandwidth': {'f_min': [0.5], 'f_max': [25]}, 'butter_order': 2, 'spectro_window_size': 256, 'f_max': 25, 'nBands': 1}
#
# MV.MBWH..SHZ ['l', 't'] 0
# class
# l    106
# t    102
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (208, 120)
# Computation time:  13.730849742889404
# Model will be trained on 2 classes [0 1] ['l' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.09093999862670898
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               l     t
#         l   106
#         t         102
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  98.4423076923  +/-  1.16802189531  %
#           Predicted class
#               l     t
#         l    52     1
#         t     1    50
# MV.MBWH..SHZ ['e', 'r'] 0
# class
# e     93
# r    110
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (203, 120)
# Computation time:  14.744574069976807
# Model will be trained on 2 classes [0 1] ['e' 'r']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.11724305152893066
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               e     r
#         e    93
#         r         110
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  77.9607843137  +/-  3.51981265448  %
#           Predicted class
#               e     r
#         e    36    11
#         r    12    43
# MV.MBWH..SHZ ['h', 'l', 't'] 0
# class
# h    106
# l    106
# t    102
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (314, 120)
# Computation time:  19.957384824752808
# Model will be trained on 3 classes [0 1 2] ['h' 'l' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.14876008033752441
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               h     l     t
#         h   106
#         l         106
#         t               102
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  83.9872611465  +/-  2.16564256243  %
#           Predicted class
#               h     l     t
#         h    39     7     7
#         l     4    49     0
#         t     7          44
# MV.MBWH..SHZ ['h', 'l', 't', 'r'] 0
# class
# h    106
# l    106
# r    110
# t    102
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (424, 120)
# Computation time:  27.79870319366455
# Model will be trained on 4 classes [0 1 2 3] ['h' 'l' 'r' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.21210718154907227
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               h     l     r     t
#         h   106
#         l         106
#         r               110
#         t                     102
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  82.1037735849  +/-  1.76344451601  %
#           Predicted class
#               h     l     r     t
#         h    37     6     3     7
#         l     2    48     3     0
#         r     4     3    46     2
#         t     6           1    44
# MV.MBWH..SHZ ['e', 'h', 'l', 't', 'r'] 0
# class
# e     93
# h    106
# l    106
# r    110
# t    102
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (517, 120)
# Computation time:  34.55080986022949
# Model will be trained on 5 classes [0 1 2 3 4] ['e' 'h' 'l' 'r' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.29080915451049805
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               e     h     l     r     t
#         e    93
#         h         106
#         l               106
#         r                     110
#         t                           102
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  76.0  +/-  1.80826932648  %
#           Predicted class
#               e     h     l     r     t
#         e    33     0     4    10
#         h     1    37     5     3     8
#         l     2     2    47     2
#         r    10     4     3    36     1
#         t     0     5           1    44
# MV.MBWH..SHZ ['l', 't'] 1
# class
# l    106
# t    102
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (208, 120)
# Computation time:  13.784121751785278
# Model will be trained on 2 classes [0 1] ['l' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.09273815155029297
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               l     t
#         l   106
#         t         102
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  98.7307692308  +/-  0.825804252061  %
#           Predicted class
#               l     t
#         l    53     0
#         t     1    50
# MV.MBWH..SHZ ['e', 'r'] 1
# class
# e     93
# r    110
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (203, 120)
# Computation time:  14.63012981414795
# Model will be trained on 2 classes [0 1] ['e' 'r']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.12373518943786621
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               e     r
#         e    93
#         r         110
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  77.0588235294  +/-  3.50755761176  %
#           Predicted class
#               e     r
#         e    36    11
#         r    12    43
# MV.MBWH..SHZ ['h', 'l', 't'] 1
# class
# h    106
# l    106
# t    102
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (314, 120)
# Computation time:  21.31330108642578
# Model will be trained on 3 classes [0 1 2] ['h' 'l' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.15529298782348633
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               h     l     t
#         h   106
#         l         106
#         t               102
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  84.3694267516  +/-  2.35655017673  %
#           Predicted class
#               h     l     t
#         h    39     7     7
#         l     3    50     0
#         t     7          44
# MV.MBWH..SHZ ['h', 'l', 't', 'r'] 1
# class
# h    106
# l    106
# r    110
# t    102
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (424, 120)
# Computation time:  27.578458070755005
# Model will be trained on 4 classes [0 1 2 3] ['h' 'l' 'r' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.21341180801391602
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               h     l     r     t
#         h   106
#         l         106
#         r               110
#         t                     102
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  82.2075471698  +/-  2.03222525332  %
#           Predicted class
#               h     l     r     t
#         h    36     6     4     8
#         l     2    48     4
#         r     4     4    46     2
#         t     5           1    45
# MV.MBWH..SHZ ['e', 'h', 'l', 't', 'r'] 1
# class
# e     93
# h    106
# l    106
# r    110
# t    102
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (517, 120)
# Computation time:  34.51652908325195
# Model will be trained on 5 classes [0 1 2 3 4] ['e' 'h' 'l' 'r' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.2904171943664551
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               e     h     l     r     t
#         e    93
#         h         106
#         l               106
#         r                     110
#         t                           102
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  75.9536679537  +/-  2.16083798392  %
#           Predicted class
#               e     h     l     r     t
#         e    34     0     4     9
#         h     1    36     6     3     7
#         l     3     2    45     3
#         r    11     4     3    36     1
#         t     0     5           1    44
# MV.MBWH..SHZ ['l', 't'] 2
# class
# l     99
# t    101
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (200, 120)
# Computation time:  12.400070190429688
# Model will be trained on 2 classes [0 1] ['l' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.09009075164794922
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               l     t
#         l    99
#         t         101
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  99.18  +/-  0.712460525222  %
#           Predicted class
#               l     t
#         l    49     0
#         t     1    50
# MV.MBWH..SHZ ['e', 'r'] 2
# class
# e    87
# r    94
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (181, 120)
# Computation time:  13.302019119262695
# Model will be trained on 2 classes [0 1] ['e' 'r']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.11131906509399414
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               e     r
#         e    87
#         r          94
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  77.3186813187  +/-  3.58962397947  %
#           Predicted class
#               e     r
#         e    36     8
#         r    12    35
# MV.MBWH..SHZ ['h', 'l', 't'] 2
# class
# h    104
# l     99
# t    101
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (304, 120)
# Computation time:  19.535098791122437
# Model will be trained on 3 classes [0 1 2] ['h' 'l' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.16198110580444336
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               h     l     t
#         h   104
#         l          99
#         t               101
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  84.9473684211  +/-  2.0914017354  %
#           Predicted class
#               h     l     t
#         h    39     7     7
#         l     3    46
#         t     6          44
# MV.MBWH..SHZ ['h', 'l', 't', 'r'] 2
# class
# h    104
# l     99
# r     94
# t    101
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (398, 120)
# Computation time:  25.762229919433594
# Model will be trained on 4 classes [0 1 2 3] ['h' 'l' 'r' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.20348286628723145
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               h     l     r     t
#         h   104
#         l          99
#         r                94
#         t                     101
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  82.1608040201  +/-  2.18173802473  %
#           Predicted class
#               h     l     r     t
#         h    37     6     3     7
#         l     2    45     2
#         r     4     4    38     1
#         t     5           1    44
# MV.MBWH..SHZ ['e', 'h', 'l', 't', 'r'] 2
# class
# e     87
# h    104
# l     99
# r     94
# t    101
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (485, 120)
# Computation time:  33.11048483848572
# Model will be trained on 5 classes [0 1 2 3 4] ['e' 'h' 'l' 'r' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.268280029296875
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               e     h     l     r     t
#         e    87
#         h         104
#         l                99
#         r                      94
#         t                           101
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  76.1069958848  +/-  1.8263632265  %
#           Predicted class
#               e     h     l     r     t
#         e    33     0     3     7
#         h     1    37     5     2     7
#         l     2     2    44     2
#         r    11     5     3    26     1
#         t     0     5           1    44
# MV.MBWH..SHZ ['l', 't'] 3
# class
# l    92
# t    99
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (191, 120)
# Computation time:  11.84165620803833
# Model will be trained on 2 classes [0 1] ['l' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.08786940574645996
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               l     t
#         l    92
#         t          99
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  98.8958333333  +/-  0.843942879189  %
#           Predicted class
#               l     t
#         l    46     0
#         t     1    49
# MV.MBWH..SHZ ['e', 'r'] 3
# class
# e    83
# r    82
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (165, 120)
# Computation time:  12.835329055786133
# Model will be trained on 2 classes [0 1] ['e' 'r']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.10956501960754395
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               e     r
#         e    83
#         r          82
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  76.0722891566  +/-  3.15110341797  %
#           Predicted class
#               e     r
#         e    34     8
#         r    12    29
# MV.MBWH..SHZ ['h', 'l', 't'] 3
# class
# h    104
# l     92
# t     99
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (295, 120)
# Computation time:  18.860615015029907
# Model will be trained on 3 classes [0 1 2] ['h' 'l' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.14000201225280762
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               h     l     t
#         h   104
#         l          92
#         t                99
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  85.0675675676  +/-  2.09023085112  %
#           Predicted class
#               h     l     t
#         h    39     6     7
#         l     3    43
#         t     6          44
# MV.MBWH..SHZ ['h', 'l', 't', 'r'] 3
# class
# h    104
# l     92
# r     82
# t     99
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (377, 120)
# Computation time:  26.22004008293152
# Model will be trained on 4 classes [0 1 2 3] ['h' 'l' 'r' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.19534802436828613
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               h     l     r     t
#         h   104
#         l          92
#         r                82
#         t                      99
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  81.8518518519  +/-  1.91721385524  %
#           Predicted class
#               h     l     r     t
#         h    37     5     3     7
#         l     3    41     2
#         r     3     4    33     1
#         t     6           1    43
# MV.MBWH..SHZ ['e', 'h', 'l', 't', 'r'] 3
# class
# e     83
# h    104
# l     92
# r     82
# t     99
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (460, 120)
# Computation time:  32.39050912857056
# Model will be trained on 5 classes [0 1 2 3 4] ['e' 'h' 'l' 'r' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.25890207290649414
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               e     h     l     r     t
#         e    83
#         h         104
#         l                92
#         r                      82
#         t                            99
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  76.8260869565  +/-  1.93319426743  %
#           Predicted class
#               e     h     l     r     t
#         e    33     0     2     6
#         h     0    38     5     1     7
#         l     1     2    41     2
#         r    11     4     3    22     1
#         t     0     5           0    43
# MV.MBLG..SHZ ['l', 't'] 0
# class
# l    105
# t     83
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (188, 120)
# Computation time:  11.93236780166626
# Model will be trained on 2 classes [0 1] ['l' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.0879359245300293
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               l     t
#         l   105
#         t          83
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  97.9361702128  +/-  1.2660915359  %
#           Predicted class
#               l     t
#         l    52     1
#         t     1    40
# MV.MBLG..SHZ ['e', 'r'] 0
# class
# e     84
# r    102
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (186, 120)
# Computation time:  13.57412314414978
# Model will be trained on 2 classes [0 1] ['e' 'r']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.11446404457092285
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               e     r
#         e    84
#         r         102
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  79.3548387097  +/-  3.24724061732  %
#           Predicted class
#               e     r
#         e    33     9
#         r    10    41
# MV.MBLG..SHZ ['h', 'l', 't'] 0
# class
# h    100
# l    105
# t     83
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (288, 120)
# Computation time:  18.527016162872314
# Model will be trained on 3 classes [0 1 2] ['h' 'l' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.1391160488128662
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               h     l     t
#         h   100
#         l         105
#         t                83
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  87.5277777778  +/-  2.52670917584  %
#           Predicted class
#               h     l     t
#         h    40     4     5
#         l     4    48     0
#         t     4     0    38
# MV.MBLG..SHZ ['h', 'l', 't', 'r'] 0
# class
# h    100
# l    105
# r    102
# t     83
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (390, 120)
# Computation time:  25.562803983688354
# Model will be trained on 4 classes [0 1 2 3] ['h' 'l' 'r' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.19550204277038574
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               h     l     r     t
#         h   100
#         l         105
#         r               102
#         t                      83
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  85.2615384615  +/-  2.42018685332  %
#           Predicted class
#               h     l     r     t
#         h    39     4     2     6
#         l     1    47     5
#         r     3     2    44     1
#         t     4     0     1    37
# MV.MBLG..SHZ ['e', 'h', 'l', 't', 'r'] 0
# class
# e     84
# h    100
# l    105
# r    102
# t     83
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (474, 120)
# Computation time:  32.02804732322693
# Model will be trained on 5 classes [0 1 2 3 4] ['e' 'h' 'l' 'r' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.2569007873535156
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               e     h     l     r     t
#         e    84
#         h         100
#         l               105
#         r                     102
#         t                            83
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  78.0421940928  +/-  2.15307322958  %
#           Predicted class
#               e     h     l     r     t
#         e    31           2     8
#         h     0    39     4     1     5
#         l     2     1    46     3
#         r    11     4     3    32     1
#         t     0     4     0     0    37
# MV.MBLG..SHZ ['l', 't'] 1
# class
# l    105
# t     83
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (188, 120)
# Computation time:  11.952432870864868
# Model will be trained on 2 classes [0 1] ['l' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.09047603607177734
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               l     t
#         l   105
#         t          83
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  98.2553191489  +/-  1.12101615935  %
#           Predicted class
#               l     t
#         l    52     0
#         t     1    40
# MV.MBLG..SHZ ['e', 'r'] 1
# class
# e     84
# r    102
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (186, 120)
# Computation time:  13.654205083847046
# Model will be trained on 2 classes [0 1] ['e' 'r']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.11040616035461426
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               e     r
#         e    84
#         r         102
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  78.3870967742  +/-  3.663811836  %
#           Predicted class
#               e     r
#         e    32    10
#         r    10    41
# MV.MBLG..SHZ ['h', 'l', 't'] 1
# class
# h    100
# l    105
# t     83
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (288, 120)
# Computation time:  18.51424217224121
# Model will be trained on 3 classes [0 1 2] ['h' 'l' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.13504290580749512
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               h     l     t
#         h   100
#         l         105
#         t                83
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  87.3888888889  +/-  2.24106593906  %
#           Predicted class
#               h     l     t
#         h    39     5     5
#         l     3    49     0
#         t     4     0    38
# MV.MBLG..SHZ ['h', 'l', 't', 'r'] 1
# class
# h    100
# l    105
# r    102
# t     83
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (390, 120)
# Computation time:  25.97871708869934
# Model will be trained on 4 classes [0 1 2 3] ['h' 'l' 'r' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.19341683387756348
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               h     l     r     t
#         h   100
#         l         105
#         r               102
#         t                      83
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  84.9435897436  +/-  1.79343532262  %
#           Predicted class
#               h     l     r     t
#         h    38     4     2     5
#         l     2    46     5
#         r     3     3    44     1
#         t     3     0     1    37
# MV.MBLG..SHZ ['e', 'h', 'l', 't', 'r'] 1
# class
# e     84
# h    100
# l    105
# r    102
# t     83
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (474, 120)
# Computation time:  32.07606601715088
# Model will be trained on 5 classes [0 1 2 3 4] ['e' 'h' 'l' 'r' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.2636380195617676
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               e     h     l     r     t
#         e    84
#         h         100
#         l               105
#         r                     102
#         t                            83
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  77.6455696203  +/-  2.35455136328  %
#           Predicted class
#               e     h     l     r     t
#         e    31     0     3     9     0
#         h     0    39     4     1     5
#         l     2     2    46     3
#         r    11     4     3    31     2
#         t     0     3           0    37
# MV.MBLG..SHZ ['l', 't'] 2
# class
# l    98
# t    82
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (180, 120)
# Computation time:  11.541266918182373
# Model will be trained on 2 classes [0 1] ['l' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.09243392944335938
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               l     t
#         l    98
#         t          82
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  98.5555555556  +/-  0.867805519545  %
#           Predicted class
#               l     t
#         l    49     0
#         t     1    40
# MV.MBLG..SHZ ['e', 'r'] 2
# class
# e    78
# r    86
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (164, 120)
# Computation time:  12.389270782470703
# Model will be trained on 2 classes [0 1] ['e' 'r']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.12084102630615234
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               e     r
#         e    78
#         r          86
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  77.4390243902  +/-  4.07579877246  %
#           Predicted class
#               e     r
#         e    32     8
#         r    11    32
# MV.MBLG..SHZ ['h', 'l', 't'] 2
# class
# h    98
# l    98
# t    82
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (278, 120)
# Computation time:  19.31305193901062
# Model will be trained on 3 classes [0 1 2] ['h' 'l' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.1389319896697998
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               h     l     t
#         h    98
#         l          98
#         t                82
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  88.3165467626  +/-  2.06794178109  %
#           Predicted class
#               h     l     t
#         h    40     5     5
#         l     3    46
#         t     4     0    37
# MV.MBLG..SHZ ['h', 'l', 't', 'r'] 2
# class
# h    98
# l    98
# r    86
# t    82
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (364, 120)
# Computation time:  24.080976009368896
# Model will be trained on 4 classes [0 1 2 3] ['h' 'l' 'r' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.18554306030273438
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               h     l     r     t
#         h    98
#         l          98
#         r                86
#         t                      82
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  84.967032967  +/-  2.12449159975  %
#           Predicted class
#               h     l     r     t
#         h    38     4     2     6
#         l     1    44     4
#         r     4     2    36     1
#         t     3     0     1    37
# MV.MBLG..SHZ ['e', 'h', 'l', 't', 'r'] 2
# class
# e    78
# h    98
# l    98
# r    86
# t    82
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (442, 120)
# Computation time:  30.87586522102356
# Model will be trained on 5 classes [0 1 2 3 4] ['e' 'h' 'l' 'r' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.24688005447387695
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               e     h     l     r     t
#         e    78
#         h          98
#         l                98
#         r                      86
#         t                            82
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  79.2126696833  +/-  1.97112714784  %
#           Predicted class
#               e     h     l     r     t
#         e    31     0     1     7
#         h     0    39     4     1     5
#         l     2     1    44     2
#         r    11     4     3    24     1
#         t     0     3     0     0    37
# MV.MBLG..SHZ ['l', 't'] 3
# class
# l    91
# t    80
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (171, 120)
# Computation time:  10.925339937210083
# Model will be trained on 2 classes [0 1] ['l' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.08747696876525879
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               l     t
#         l    91
#         t          80
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  98.5813953488  +/-  0.781409191461  %
#           Predicted class
#               l     t
#         l    46     0
#         t     1    39
# MV.MBLG..SHZ ['e', 'r'] 3
# class
# e    74
# r    75
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (149, 120)
# Computation time:  11.229801893234253
# Model will be trained on 2 classes [0 1] ['e' 'r']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.10044121742248535
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               e     r
#         e    74
#         r          75
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  76.9066666667  +/-  4.65285575391  %
#           Predicted class
#               e     r
#         e    31     6
#         r    12    26
# MV.MBLG..SHZ ['h', 'l', 't'] 3
# class
# h    98
# l    91
# t    80
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (269, 120)
# Computation time:  17.481290102005005
# Model will be trained on 3 classes [0 1 2] ['h' 'l' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.12908697128295898
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               h     l     t
#         h    98
#         l          91
#         t                80
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  88.2814814815  +/-  2.27439978365  %
#           Predicted class
#               h     l     t
#         h    40     4     5
#         l     3    43
#         t     3     0    36
# MV.MBLG..SHZ ['h', 'l', 't', 'r'] 3
# class
# h    98
# l    91
# r    75
# t    80
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (344, 120)
# Computation time:  22.71245288848877
# Model will be trained on 4 classes [0 1 2 3] ['h' 'l' 'r' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.17772698402404785
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               h     l     r     t
#         h    98
#         l          91
#         r                75
#         t                      80
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  85.2558139535  +/-  2.19320944239  %
#           Predicted class
#               h     l     r     t
#         h    38     4     2     5
#         l     1    41     3
#         r     3     2    31     1
#         t     3     0     1    36
# MV.MBLG..SHZ ['e', 'h', 'l', 't', 'r'] 3
# class
# e    74
# h    98
# l    91
# r    75
# t    80
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (418, 120)
# Computation time:  28.913460969924927
# Model will be trained on 5 classes [0 1 2 3 4] ['e' 'h' 'l' 'r' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.23320913314819336
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               e     h     l     r     t
#         e    74
#         h          98
#         l                91
#         r                      75
#         t                            80
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  79.7894736842  +/-  2.3215555563  %
#           Predicted class
#               e     h     l     r     t
#         e    31           1     5
#         h     0    39     4     1     5
#         l     1     1    41     2
#         r    10     3     3    20     1
#         t     0     4     0     0    36
# MV.MBRY..SHZ ['l', 't'] 0
# class
# l    89
# t    86
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (175, 120)
# Computation time:  12.5384042263031
# Model will be trained on 2 classes [0 1] ['l' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.09595489501953125
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               l     t
#         l    89
#         t          86
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  96.3863636364  +/-  1.60207123169  %
#           Predicted class
#               l     t
#         l    44     1
#         t     2    41
# MV.MBRY..SHZ ['e', 'r'] 0
# class
# e    83
# r    94
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (177, 120)
# Computation time:  13.260645151138306
# Model will be trained on 2 classes [0 1] ['e' 'r']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.15938615798950195
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               e     r
#         e    83
#         r          94
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  76.9438202247  +/-  3.49031520276  %
#           Predicted class
#               e     r
#         e    34     8
#         r    12    35
# MV.MBRY..SHZ ['h', 'l', 't'] 0
# class
# h    100
# l     89
# t     86
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (275, 120)
# Computation time:  18.040884017944336
# Model will be trained on 3 classes [0 1 2] ['h' 'l' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.1495521068572998
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               h     l     t
#         h   100
#         l          89
#         t                86
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  87.3043478261  +/-  2.41746776371  %
#           Predicted class
#               h     l     t
#         h    41     5     4
#         l     3    41     1
#         t     4     0    39
# MV.MBRY..SHZ ['h', 'l', 't', 'r'] 0
# class
# h    100
# l     89
# r     94
# t     86
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (369, 120)
# Computation time:  24.347887992858887
# Model will be trained on 4 classes [0 1 2 3] ['h' 'l' 'r' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.19324803352355957
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               h     l     r     t
#         h   100
#         l          89
#         r                94
#         t                      86
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  84.9945945946  +/-  2.47130500536  %
#           Predicted class
#               h     l     r     t
#         h    38     5     3     4
#         l     3    40     2     0
#         r     3     3    40     1
#         t     4     0     0    39
# MV.MBRY..SHZ ['e', 'h', 'l', 't', 'r'] 0
# class
# e     83
# h    100
# l     89
# r     94
# t     86
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (452, 120)
# Computation time:  30.82752013206482
# Model will be trained on 5 classes [0 1 2 3 4] ['e' 'h' 'l' 'r' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.278033971786499
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               e     h     l     r     t
#         e    83
#         h         100
#         l                89
#         r                      94
#         t                            86
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  79.0442477876  +/-  2.10306899768  %
#           Predicted class
#               e     h     l     r     t
#         e    34           1     6
#         h     1    38     5     2     4
#         l     1     2    40     2     0
#         r    13     3     2    28     1
#         t     0     4           0    39
# MV.MBRY..SHZ ['l', 't'] 1
# class
# l    89
# t    86
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (175, 120)
# Computation time:  11.06364893913269
# Model will be trained on 2 classes [0 1] ['l' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.08657622337341309
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               l     t
#         l    89
#         t          86
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  96.5681818182  +/-  1.85321364835  %
#           Predicted class
#               l     t
#         l    44     1
#         t     2    41
# MV.MBRY..SHZ ['e', 'r'] 1
# class
# e    83
# r    94
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (177, 120)
# Computation time:  12.921718835830688
# Model will be trained on 2 classes [0 1] ['e' 'r']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.14972805976867676
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               e     r
#         e    83
#         r          94
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  76.0  +/-  3.78543311267  %
#           Predicted class
#               e     r
#         e    34     8
#         r    13    34
# MV.MBRY..SHZ ['h', 'l', 't'] 1
# class
# h    100
# l     89
# t     86
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (275, 120)
# Computation time:  17.65840196609497
# Model will be trained on 3 classes [0 1 2] ['h' 'l' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.13477087020874023
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               h     l     t
#         h   100
#         l          89
#         t                86
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  87.4637681159  +/-  2.08640290564  %
#           Predicted class
#               h     l     t
#         h    41     5     4
#         l     4    41     0
#         t     4          39
# MV.MBRY..SHZ ['h', 'l', 't', 'r'] 1
# class
# h    100
# l     89
# r     94
# t     86
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (369, 120)
# Computation time:  25.464305877685547
# Model will be trained on 4 classes [0 1 2 3] ['h' 'l' 'r' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.20598602294921875
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               h     l     r     t
#         h   100
#         l          89
#         r                94
#         t                      86
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  84.8432432432  +/-  1.74974901675  %
#           Predicted class
#               h     l     r     t
#         h    38     5     3     4
#         l     3    40     2     0
#         r     3     2    40     1
#         t     4     0     1    38
# MV.MBRY..SHZ ['e', 'h', 'l', 't', 'r'] 1
# class
# e     83
# h    100
# l     89
# r     94
# t     86
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (452, 120)
# Computation time:  30.862021923065186
# Model will be trained on 5 classes [0 1 2 3 4] ['e' 'h' 'l' 'r' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.26190900802612305
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               e     h     l     r     t
#         e    83
#         h         100
#         l                89
#         r                      94
#         t                            86
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  79.1327433628  +/-  1.99529558702  %
#           Predicted class
#               e     h     l     r     t
#         e    34     0     1     6
#         h     1    38     5     2     4
#         l     1     2    40     2     0
#         r    12     3     3    28     1
#         t     0     4           0    39
# MV.MBRY..SHZ ['l', 't'] 2
# class
# l    83
# t    85
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (168, 120)
# Computation time:  10.647823095321655
# Model will be trained on 2 classes [0 1] ['l' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.08771896362304688
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               l     t
#         l    83
#         t          85
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  97.119047619  +/-  1.71841434055  %
#           Predicted class
#               l     t
#         l    41     0
#         t     2    41
# MV.MBRY..SHZ ['e', 'r'] 2
# class
# e    80
# r    80
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (160, 120)
# Computation time:  12.641688108444214
# Model will be trained on 2 classes [0 1] ['e' 'r']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.1461048126220703
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               e     r
#         e    80
#         r          80
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  76.575  +/-  3.9036041039  %
#           Predicted class
#               e     r
#         e    34     6
#         r    13    27
# MV.MBRY..SHZ ['h', 'l', 't'] 2
# class
# h    98
# l    83
# t    85
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (266, 120)
# Computation time:  17.229398012161255
# Model will be trained on 3 classes [0 1 2] ['h' 'l' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.13794207572937012
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               h     l     t
#         h    98
#         l          83
#         t                85
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  87.0977443609  +/-  2.81070291548  %
#           Predicted class
#               h     l     t
#         h    39     6     4
#         l     3    38     1
#         t     4          38
# MV.MBRY..SHZ ['h', 'l', 't', 'r'] 2
# class
# h    98
# l    83
# r    80
# t    85
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (346, 120)
# Computation time:  22.784228086471558
# Model will be trained on 4 classes [0 1 2 3] ['h' 'l' 'r' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.18088388442993164
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               h     l     r     t
#         h    98
#         l          83
#         r                80
#         t                      85
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  84.8439306358  +/-  2.45045803109  %
#           Predicted class
#               h     l     r     t
#         h    39     4     3     3
#         l     3    38     1
#         r     4     2    33     1
#         t     4     0     0    38
# MV.MBRY..SHZ ['e', 'h', 'l', 't', 'r'] 2
# class
# e    80
# h    98
# l    83
# r    80
# t    85
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (426, 120)
# Computation time:  29.303237199783325
# Model will be trained on 5 classes [0 1 2 3 4] ['e' 'h' 'l' 'r' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.24493169784545898
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               e     h     l     r     t
#         e    80
#         h          98
#         l                83
#         r                      80
#         t                            85
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  78.9953051643  +/-  2.18157855103  %
#           Predicted class
#               e     h     l     r     t
#         e    34     0     0     6
#         h     1    38     5     2     4
#         l     1     2    38     1
#         r    12     3     2    21     1
#         t     0     4           0    38
# MV.MBRY..SHZ ['l', 't'] 3
# class
# l    76
# t    83
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (159, 120)
# Computation time:  10.052103757858276
# Model will be trained on 2 classes [0 1] ['l' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.08821511268615723
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               l     t
#         l    76
#         t          83
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  97.675  +/-  1.56144964696  %
#           Predicted class
#               l     t
#         l    38     0
#         t     2    40
# MV.MBRY..SHZ ['e', 'r'] 3
# class
# e    76
# r    71
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (147, 120)
# Computation time:  11.062157154083252
# Model will be trained on 2 classes [0 1] ['e' 'r']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.13945698738098145
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               e     r
#         e    76
#         r          71
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  76.1891891892  +/-  3.37448424217  %
#           Predicted class
#               e     r
#         e    34     4
#         r    14    22
# MV.MBRY..SHZ ['h', 'l', 't'] 3
# class
# h    98
# l    76
# t    83
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (257, 120)
# Computation time:  16.487128973007202
# Model will be trained on 3 classes [0 1 2] ['h' 'l' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.13293695449829102
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               h     l     t
#         h    98
#         l          76
#         t                83
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  86.8682170543  +/-  2.35337397971  %
#           Predicted class
#               h     l     t
#         h    40     5     4
#         l     4    34
#         t     4          38
# MV.MBRY..SHZ ['h', 'l', 't', 'r'] 3
# class
# h    98
# l    76
# r    71
# t    83
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (328, 120)
# Computation time:  21.63285517692566
# Model will be trained on 4 classes [0 1 2 3] ['h' 'l' 'r' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.1840817928314209
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               h     l     r     t
#         h    98
#         l          76
#         r                71
#         t                      83
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  85.0365853659  +/-  2.79747166379  %
#           Predicted class
#               h     l     r     t
#         h    38     4     2     4
#         l     3    34     1
#         r     3     2    30     1
#         t     4           0    37
# MV.MBRY..SHZ ['e', 'h', 'l', 't', 'r'] 3
# class
# e    76
# h    98
# l    76
# r    71
# t    83
# dtype: int64
# /Users/thompsong/src/AAA-master/MONTSERRAT/catalog/MVO_labelled_events_filtered.pd
#
#
#  *** ANALYZER ***
# Training data have been read and features have been extracted  (404, 120)
# Computation time:  27.642740964889526
# Model will be trained on 5 classes [0 1 2 3 4] ['e' 'h' 'l' 'r' 't']
# Features have been scaled
# Model has been trained:  RandomForestClassifier(criterion='entropy')
# Computation time:  0.22667789459228516
# Model score is:  1.0
# and associated confusion matrix is:
#           Predicted class
#               e     h     l     r     t
#         e    76
#         h          98
#         l                76
#         r                      71
#         t                            83
# StratifiedShuffleSplit(n_splits=50, random_state=None, test_size=0.5,
#             train_size=0.5)
# Cross-validation results:  78.5841584158  +/-  2.02380209606  %
#           Predicted class
#               e     h     l     r     t
#         e    33     0     0     5
#         h     1    39     4     2     4
#         l     1     3    33     1
#         r    13     4     2    16     1
#         t     0     4           0    37
# Done
