# %%
"""

"""

""" 
This workflow is good. The short-term goal is to process all S-files and make use of the
information in the S-files. But now I know I can also correct the corresponding WAV files,
and make pickle files and spectrogram plots for them, etc.

I still need to work on ways to get trace metrics to dataframe and summarize on webpage.

And then to make CSV files (one per event), improving the 2019 IPGP workflow.

And then decide how to choose the best events.

"""

import sys, os
sys.path.append('%s/src/kitchensinkGT/LIB' % os.getenv('HOME'))
from Sfile import Sfile
sfilebase = '01-0242-12L.S199901'
sfilebase = '01-0149-37R.S200505'
DB = 'MVOE_'
sfilepath = os.path.join(os.getenv('HOME'),'DATA','MVO', 'REA', DB, sfilebase[-6:-2], sfilebase[-2:], sfilebase)
sfileobj = Sfile(sfilepath)
sfileobj.cat()
sfileobj.read_event()
print(sfileobj)

s = sfileobj
print(s.mainclass, s.subclass, s.agency, s.magnitude, s.latitude, s.longitude, )

evobj = sfileobj.events

print(evobj)
print(' ')
for originobj in evobj.origins:
    print(originobj)
print(' ')
print(evobj.event_descriptions)
# Out:
#  2005  5 1 0149 36.2 R  16.092 -61.397  0.0  MVO  7 0.1                        1
#  2005 0501 0149 37.0 R  15.889 -61.577 32.0  SRU 10     3.2                    1
#  GAP=355        0.31     999.9   999.9847.5 -0.2533E+07  0.1486E+07 -0.1225E+07E
#  2005  5 1 0149 36.232  16.09168  -61.39717    0.019  0.071                    H
#  ACTION:UP  05-05-03 09:48 OP:vab  STATUS:               ID:20050501014937     I
#  2005-05-01-0149-37S.MVO___025                                                 6
#  STAT SP IPHASW D HRMM SECON CODA AMPLIT PERI AZIMU VELO AIN AR TRES W  DIS CAZ7
#  MBBY BZ EP        14956.218                              21     0.110  109 308
#  MBBY BE ES        15011.035                              21     0.010  109 308
#  MBHA BZ EP        14956.156                              21    -0.110  109 311
#  MBLY BZ EP        14956.249                              21     0.010  110 310
#  MBGH BZ EP        14956.523                              21     0.010  111 309
#  MBWH BZ EP        14956.398                              21    -0.110  111 310
#  MBGB BZ EP        14956.799                              21     0.010  114 309
#  MBRV SZ EP        14957.338                              21     0.110  117 313
#
#
# Processing:  2005  5 1 0149 36.2 R  16.092 -61.397  0.0  MVO  7 0.1                        1
#
# Processing:  2005 0501 0149 37.0 R  15.889 -61.577 32.0  SRU 10     3.2                    1
#
# wavfile =  2005-05-01-0149-37S.MVO___025
# 2005 05 01 01 49 37
# S-file path: /Users/thompsong/DATA/MVO/REA/MVOE_/2005/05/01-0149-37R.S200505
# 	File time: 2005-05-01 01:49:37.000000
# 	Origin time: 2005-05-01 01:49:36.231999
# 	Mainclass: R
# 	Longitude: -61.397170
# 	Latitude: 16.091680
# 	Depth: 0.019000
# 	Agency: SRU
# 	Id: 20050501014937
# 	rms: 0.071000
# 	Magnitude: 3.2,  ,
# 	Last action: UP
# 	Last action time: 05-05-03 09:48
# 	Analyst: vab
# 	Gap: 355
# 	Error: {'covxy': -2533000.0,
#  'covxz': 1486000.0,
#  'covyz': -1225000.0,
#  'depth': 847.5,
#  'latitude': 999.9,
#  'longitude': 999.9,
#  'origintime': 0.31}
# 	Number of arrivals: 8
# 	Arrivals:Pick
# 	 resource_id: ResourceIdentifier(id="smi:local/362539bd-9ab4-449a-92d4-da901443edfe")
# 	        time: UTCDateTime(2005, 5, 1, 1, 49, 56, 218000) [uncertainty=0.1]
# 	 waveform_id: WaveformStreamID(network_code='..MBBY..BZ')
# 	 backazimuth: 188.0
# 	       onset: 'emergent'
# 	  phase_hint: 'P'Pick
# 	 resource_id: ResourceIdentifier(id="smi:local/7ab4af0b-be1b-4bf2-8a5b-60bff696a92e")
# 	        time: UTCDateTime(2005, 5, 1, 1, 50, 11, 35000) [uncertainty=0.0]
# 	 waveform_id: WaveformStreamID(network_code='..MBBY..BE')
# 	 backazimuth: 188.0
# 	       onset: 'emergent'
# 	  phase_hint: 'S'Pick
# 	 resource_id: ResourceIdentifier(id="smi:local/336f208b-07ef-4ffc-aa2c-39a724dc4c12")
# 	        time: UTCDateTime(2005, 5, 1, 1, 49, 56, 156000) [uncertainty=-0.1]
# 	 waveform_id: WaveformStreamID(network_code='..MBHA..BZ')
# 	 backazimuth: 191.0
# 	       onset: 'emergent'
# 	  phase_hint: 'P'Pick
# 	 resource_id: ResourceIdentifier(id="smi:local/149e4b68-3592-4248-a7de-021d98a2b956")
# 	        time: UTCDateTime(2005, 5, 1, 1, 49, 56, 249000) [uncertainty=0.0]
# 	 waveform_id: WaveformStreamID(network_code='..MBLY..BZ')
# 	 backazimuth: 190.0
# 	       onset: 'emergent'
# 	  phase_hint: 'P'Pick
# 	 resource_id: ResourceIdentifier(id="smi:local/79af38d4-6b7b-443a-92e1-eeb0272a5de4")
# 	        time: UTCDateTime(2005, 5, 1, 1, 49, 56, 523000) [uncertainty=0.0]
# 	 waveform_id: WaveformStreamID(network_code='..MBGH..BZ')
# 	 backazimuth: 189.0
# 	       onset: 'emergent'
# 	  phase_hint: 'P'Pick
# 	 resource_id: ResourceIdentifier(id="smi:local/86348327-85e4-4ab8-8a87-7526d9258971")
# 	        time: UTCDateTime(2005, 5, 1, 1, 49, 56, 398000) [uncertainty=-0.1]
# 	 waveform_id: WaveformStreamID(network_code='..MBWH..BZ')
# 	 backazimuth: 190.0
# 	       onset: 'emergent'
# 	  phase_hint: 'P'Pick
# 	 resource_id: ResourceIdentifier(id="smi:local/b27c7262-86c1-4507-bea1-ea665a0a40da")
# 	        time: UTCDateTime(2005, 5, 1, 1, 49, 56, 799000) [uncertainty=0.0]
# 	 waveform_id: WaveformStreamID(network_code='..MBGB..BZ')
# 	 backazimuth: 189.0
# 	       onset: 'emergent'
# 	  phase_hint: 'P'Pick
# 	 resource_id: ResourceIdentifier(id="smi:local/50f6f3f6-1f8f-45a9-8eda-3922cf56f9de")
# 	        time: UTCDateTime(2005, 5, 1, 1, 49, 57, 338000) [uncertainty=0.1]
# 	 waveform_id: WaveformStreamID(network_code='..MBRV..SZ')
# 	 backazimuth: 193.0
# 	       onset: 'emergent'
# 	  phase_hint: 'P'
# 	WAV files:
# 		wavfile: /Users/thompsong/DATA/MVO/WAV/MVOE_/2005/05/2005-05-01-0149-37S.MVO___025
# 	Events:
# 		resource_id
# 		event_type
# 		event_type_certainty
# 		creation_info
# 		preferred_origin_id
# 		preferred_magnitude_id
# 		preferred_focal_mechanism_id
# 		event_descriptions
# 		comments
# 		picks
# 		amplitudes
# 		focal_mechanisms
# 		origins
# 		magnitudes
# 		station_magnitudes
# R None SRU [3.2] 16.09168 -61.39717
# Event:	2005-05-01T01:49:36.200000Z | +16.092,  -61.397
#
# 	         resource_id: ResourceIdentifier(id="smi:local/4c2cac9b-3f8a-4731-bf64-ac7d783e55fc")
# 	       creation_info: CreationInfo(agency_id='MVO')
# 	 preferred_origin_id: ResourceIdentifier(id="smi:local/75fab9f3-e14b-4dc6-ab1d-c747ef951246")
# 	                ---------
# 	  event_descriptions: 2 Elements
# 	             origins: 2 Elements
#
# Origin
# 	   resource_id: ResourceIdentifier(id="smi:local/75fab9f3-e14b-4dc6-ab1d-c747ef951246")
# 	          time: UTCDateTime(2005, 5, 1, 1, 49, 36, 200000)
# 	     longitude: -61.397
# 	      latitude: 16.092
# 	         depth: 0.0
# 	       quality: OriginQuality(used_station_count=7, standard_error=0.1)
# 	 creation_info: CreationInfo(agency_id='MVO')
# Origin
# 	   resource_id: ResourceIdentifier(id="smi:local/c80a4f4b-42da-4d73-9cd4-c64aa77ddcb6")
# 	          time: UTCDateTime(2005, 5, 1, 1, 49, 37)
# 	     longitude: -61.577
# 	      latitude: 15.889
# 	         depth: 32000.0
# 	       quality: OriginQuality(used_station_count=10)
# 	 creation_info: CreationInfo(agency_id='SRU')
#
# [EventDescription(text='R '), EventDescription(text='R ')]

# %%
for w in s.wavfiles:
    print(w)
    w.read()
    w.plot()
# Out:
# wavfile: /Users/thompsong/DATA/MVO/WAV/MVOE_/2005/05/2005-05-01-0149-37S.MVO___025
