# %% [markdown]
# # Explore the SEA-CALIPSO data

# %%
import os
TOPDIR = '/Users/thompsong/SEA-CALIPSO-SHARE/Data'
SEISANDIR = os.path.join(TOPDIR, 'seisan')
WAVDIR = os.path.join(SEISANDIR, 'WAV', 'MOBS_', '2007', '12')
from obspy import read
seisanwavfile = '2007-12-14-0100-04M.MOBS__003'
st = read(os.path.join(WAVDIR, seisanwavfile))
st.plot();

# %%
SEGYDIR = os.path.join(TOPDIR, 'SEGYOBS_CONTINUOUS', 'segy2')
segyfile = 'SN02_Line01_Site08_02_ch3.segy'
st2 = read(os.path.join(SEGYDIR, segyfile), 'SEGY')
st2.plot();
