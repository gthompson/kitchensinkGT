# %%
# %run header.ipynb
print(paths)

preconfigured = True

if not preconfigured:
    # PRE-CONFIGURE CONFIGURATION
    startt = UTCDateTime(2022,8,1)
    endt = UTCDateTime(2022,12,5)
    SDS_TOP=os.path.join(os.getenv('HOME'), 'Dropbox', 'DATA', 'SDS')

    # get list of trace_ids from SDS archive
    thisSDSobj = SDS.SDSobj(paths['SDS_TOP'])
    trace_ids = thisSDSobj._sds_get_nonempty_traceids(startt, endt)
    print(trace_ids)

    for id in trace_ids:
        keepRaw = True
        sgram = False
        if id[-1] in 'ZNEF123456789' and id[-2] in 'HD':
            keepRaw = False
            if id[-1] in 'ZF4' and id[-2] in 'HD':
                sgram = True
        print(f"{id},{subnet},None,{keepRaw},{sgram}")
        # These have been appended to trace_ids config csv


# how do we create an inventory for the KSC network?
    # there is nothing to do for the well stations. they are already calibrated.
    # for the seismic and infrasound stations, we need appropriate responses for:
        # Trillum + Centaur
        # InfraBSU + Centaur
        # Chaparral M25 + Centaur
    # The shortcut is if there is no inv, just to supply calibration information from counts 2 Pa, and counts to m/s.
        # calibration info should be in the trace_ids config. would be 1 for well channels.
        # no Drs calculation if no inv.
        # but can still do CSAM and spectrograms.
        # could potentially do reduced velocity, and reduced pressure.
        # maybe the whole idea of reduced displacement is silly, and just do reduced velocity instead? or as well as?
    # TO DO:
        # add other parameters, from metrics.py. but get traditional iceweb stuff working first.

# %%
# RUN JOB
# call the wrapper
#os.system('rm /Users/thompsong/IceWeb/*.db')
#importlib.reload(wrappers)
print(os.name)
if os.name=='nt':
    wrappers.run_iceweb_job(subnet, configdir=paths['CONFIGDIR'], configname=subnet )
elif os.name=='darwin':
    wrappers.run_iceweb_job(subnet, configdir='config', configname='laptop' )
# Out:
# nt
# Timewindow:  2022-04-01T00:00:00.000000Z 2022-12-03T00:00:00.000000Z
# D:/ROCKETSEIS/SDS\metadata\28.608389_-80.604333_20220401_20221203_0.18099547511312217.sml does not exist
# sqlite version: 2.6.0
#
#
# Time now: 2023-11-08T13:38:27.599435
# Processing 2022-04-01T00:00:00.000000Z
# Inserted new row for KSC_2022-04-01T00:00:00_2022-04-01T01:00:00
# Got a lock on KSC_2022-04-01T00:00:00_2022-04-01T01:00:00
#
#
# Time now: 2023-11-08T13:38:31.339668
# ('KSC', '2022-04-01T00:00:00', '2022-04-01T01:00:00', None, 0, 0, 0, 0, 1)
# Got a lock on KSC_2022-04-01T00:00:00_2022-04-01T01:00:00
# ('KSC', '2022-04-01T00:00:00', '2022-04-01T01:00:00', None, 0, 0, 0, 0, 1)
# FL.BCHH2.10.HD4 absolute= True
# FL.BCHH2.10.HD5 absolute= True
# FL.BCHH2.10.HD6 absolute= True
# FL.BCHH2.10.HD7 absolute= True
# FL.BCHH2.10.HD8 absolute= True
# FL.BCHH2.10.HD9 absolute= True
# FL.S39A2.00.HHE absolute= True
# FL.S39A2.00.HHN absolute= True
# FL.S39A2.00.HHZ absolute= True
# FL.S39A2.10.HDF absolute= True
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD4_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD5_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD6_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD7_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD8_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD9_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHE_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHN_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHZ_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.10.HDF_2022.csv
# ('KSC', '2022-04-01T00:00:00', '2022-04-01T01:00:00', None, 1, 0, 0, 0, 1)
# KSC_2022-04-01T00:00:00_2022-04-01T01:00:00 unlocked
# ('KSC', '2022-04-01T00:00:00', '2022-04-01T01:00:00', None, 1, 0, 0, 0, 0)
# KSC_2022-04-01T00:00:00_2022-04-01T01:00:00 was not locked
#
#
# Time now: 2023-11-08T13:38:34.590633
# Processing 2022-04-01T01:00:00.000000Z
# Inserted new row for KSC_2022-04-01T01:00:00_2022-04-01T02:00:00
# Got a lock on KSC_2022-04-01T01:00:00_2022-04-01T02:00:00
#
#
# Time now: 2023-11-08T13:38:35.211632
# ('KSC', '2022-04-01T01:00:00', '2022-04-01T02:00:00', None, 0, 0, 0, 0, 1)
# Got a lock on KSC_2022-04-01T01:00:00_2022-04-01T02:00:00
# ('KSC', '2022-04-01T01:00:00', '2022-04-01T02:00:00', None, 0, 0, 0, 0, 1)
# FL.BCHH2.10.HD4 absolute= True
# FL.BCHH2.10.HD5 absolute= True
# FL.BCHH2.10.HD6 absolute= True
# FL.BCHH2.10.HD7 absolute= True
# FL.BCHH2.10.HD8 absolute= True
# FL.BCHH2.10.HD9 absolute= True
# FL.S39A2.00.HHE absolute= True
# FL.S39A2.00.HHN absolute= True
# FL.S39A2.00.HHZ absolute= True
# FL.S39A2.10.HDF absolute= True
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD4_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD5_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD6_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD7_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD8_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD9_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHE_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHN_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHZ_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.10.HDF_2022.csv
# ('KSC', '2022-04-01T01:00:00', '2022-04-01T02:00:00', None, 1, 0, 0, 0, 1)
# KSC_2022-04-01T01:00:00_2022-04-01T02:00:00 unlocked
# ('KSC', '2022-04-01T01:00:00', '2022-04-01T02:00:00', None, 1, 0, 0, 0, 0)
# KSC_2022-04-01T01:00:00_2022-04-01T02:00:00 was not locked
#
#
# Time now: 2023-11-08T13:38:36.765303
# Processing 2022-04-01T02:00:00.000000Z
# Inserted new row for KSC_2022-04-01T02:00:00_2022-04-01T03:00:00
# Got a lock on KSC_2022-04-01T02:00:00_2022-04-01T03:00:00
#
#
# Time now: 2023-11-08T13:38:37.424301
# ('KSC', '2022-04-01T02:00:00', '2022-04-01T03:00:00', None, 0, 0, 0, 0, 1)
# Got a lock on KSC_2022-04-01T02:00:00_2022-04-01T03:00:00
# ('KSC', '2022-04-01T02:00:00', '2022-04-01T03:00:00', None, 0, 0, 0, 0, 1)
# FL.BCHH2.10.HD4 absolute= True
# FL.BCHH2.10.HD5 absolute= True
# FL.BCHH2.10.HD6 absolute= True
# FL.BCHH2.10.HD7 absolute= True
# FL.BCHH2.10.HD8 absolute= True
# FL.BCHH2.10.HD9 absolute= True
# FL.S39A2.00.HHE absolute= True
# FL.S39A2.00.HHN absolute= True
# FL.S39A2.00.HHZ absolute= True
# FL.S39A2.10.HDF absolute= True
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD4_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD5_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD6_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD7_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD8_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD9_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHE_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHN_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHZ_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.10.HDF_2022.csv
# ('KSC', '2022-04-01T02:00:00', '2022-04-01T03:00:00', None, 1, 0, 0, 0, 1)
# KSC_2022-04-01T02:00:00_2022-04-01T03:00:00 unlocked
# ('KSC', '2022-04-01T02:00:00', '2022-04-01T03:00:00', None, 1, 0, 0, 0, 0)
# KSC_2022-04-01T02:00:00_2022-04-01T03:00:00 was not locked
#
#
# Time now: 2023-11-08T13:38:38.814201
# Processing 2022-04-01T03:00:00.000000Z
# Inserted new row for KSC_2022-04-01T03:00:00_2022-04-01T04:00:00
# Got a lock on KSC_2022-04-01T03:00:00_2022-04-01T04:00:00
#
#
# Time now: 2023-11-08T13:38:39.419202
# ('KSC', '2022-04-01T03:00:00', '2022-04-01T04:00:00', None, 0, 0, 0, 0, 1)
# Got a lock on KSC_2022-04-01T03:00:00_2022-04-01T04:00:00
# ('KSC', '2022-04-01T03:00:00', '2022-04-01T04:00:00', None, 0, 0, 0, 0, 1)
# FL.BCHH2.10.HD4 absolute= True
# FL.BCHH2.10.HD5 absolute= True
# FL.BCHH2.10.HD6 absolute= True
# FL.BCHH2.10.HD7 absolute= True
# FL.BCHH2.10.HD8 absolute= True
# FL.BCHH2.10.HD9 absolute= True
# FL.S39A2.00.HHE absolute= True
# FL.S39A2.00.HHN absolute= True
# FL.S39A2.00.HHZ absolute= True
# FL.S39A2.10.HDF absolute= True
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD4_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD5_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD6_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD7_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD8_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD9_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHE_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHN_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHZ_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.10.HDF_2022.csv
# ('KSC', '2022-04-01T03:00:00', '2022-04-01T04:00:00', None, 1, 0, 0, 0, 1)
# KSC_2022-04-01T03:00:00_2022-04-01T04:00:00 unlocked
# ('KSC', '2022-04-01T03:00:00', '2022-04-01T04:00:00', None, 1, 0, 0, 0, 0)
# KSC_2022-04-01T03:00:00_2022-04-01T04:00:00 was not locked
#
#
# Time now: 2023-11-08T13:38:40.817283
# Processing 2022-04-01T04:00:00.000000Z
# Inserted new row for KSC_2022-04-01T04:00:00_2022-04-01T05:00:00
# Got a lock on KSC_2022-04-01T04:00:00_2022-04-01T05:00:00
#
#
# Time now: 2023-11-08T13:38:41.530278
# ('KSC', '2022-04-01T04:00:00', '2022-04-01T05:00:00', None, 0, 0, 0, 0, 1)
# Got a lock on KSC_2022-04-01T04:00:00_2022-04-01T05:00:00
# ('KSC', '2022-04-01T04:00:00', '2022-04-01T05:00:00', None, 0, 0, 0, 0, 1)
# FL.BCHH2.10.HD4 absolute= True
# FL.BCHH2.10.HD5 absolute= True
# FL.BCHH2.10.HD6 absolute= True
# FL.BCHH2.10.HD7 absolute= True
# FL.BCHH2.10.HD8 absolute= True
# FL.BCHH2.10.HD9 absolute= True
# FL.S39A2.00.HHE absolute= True
# FL.S39A2.00.HHN absolute= True
# FL.S39A2.00.HHZ absolute= True
# FL.S39A2.10.HDF absolute= True
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD4_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD5_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD6_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD7_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD8_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD9_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHE_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHN_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHZ_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.10.HDF_2022.csv
# ('KSC', '2022-04-01T04:00:00', '2022-04-01T05:00:00', None, 1, 0, 0, 0, 1)
# KSC_2022-04-01T04:00:00_2022-04-01T05:00:00 unlocked
# ('KSC', '2022-04-01T04:00:00', '2022-04-01T05:00:00', None, 1, 0, 0, 0, 0)
# KSC_2022-04-01T04:00:00_2022-04-01T05:00:00 was not locked
#
#
# Time now: 2023-11-08T13:38:43.222115
# Processing 2022-04-01T05:00:00.000000Z
# Inserted new row for KSC_2022-04-01T05:00:00_2022-04-01T06:00:00
# Got a lock on KSC_2022-04-01T05:00:00_2022-04-01T06:00:00
#
#
# Time now: 2023-11-08T13:38:43.828124
# ('KSC', '2022-04-01T05:00:00', '2022-04-01T06:00:00', None, 0, 0, 0, 0, 1)
# Got a lock on KSC_2022-04-01T05:00:00_2022-04-01T06:00:00
# ('KSC', '2022-04-01T05:00:00', '2022-04-01T06:00:00', None, 0, 0, 0, 0, 1)
# FL.BCHH2.10.HD4 absolute= True
# FL.BCHH2.10.HD5 absolute= True
# FL.BCHH2.10.HD6 absolute= True
# FL.BCHH2.10.HD7 absolute= True
# FL.BCHH2.10.HD8 absolute= True
# FL.BCHH2.10.HD9 absolute= True
# FL.S39A2.00.HHE absolute= True
# FL.S39A2.00.HHN absolute= True
# FL.S39A2.00.HHZ absolute= True
# FL.S39A2.10.HDF absolute= True
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD4_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD5_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD6_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD7_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD8_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD9_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHE_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHN_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHZ_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.10.HDF_2022.csv
# ('KSC', '2022-04-01T05:00:00', '2022-04-01T06:00:00', None, 1, 0, 0, 0, 1)
# KSC_2022-04-01T05:00:00_2022-04-01T06:00:00 unlocked
# ('KSC', '2022-04-01T05:00:00', '2022-04-01T06:00:00', None, 1, 0, 0, 0, 0)
# KSC_2022-04-01T05:00:00_2022-04-01T06:00:00 was not locked
#
#
# Time now: 2023-11-08T13:38:45.265664
# Processing 2022-04-01T06:00:00.000000Z
# Inserted new row for KSC_2022-04-01T06:00:00_2022-04-01T07:00:00
# Got a lock on KSC_2022-04-01T06:00:00_2022-04-01T07:00:00
#
#
# Time now: 2023-11-08T13:38:45.884673
# ('KSC', '2022-04-01T06:00:00', '2022-04-01T07:00:00', None, 0, 0, 0, 0, 1)
# Got a lock on KSC_2022-04-01T06:00:00_2022-04-01T07:00:00
# ('KSC', '2022-04-01T06:00:00', '2022-04-01T07:00:00', None, 0, 0, 0, 0, 1)
# FL.BCHH2.10.HD4 absolute= True
# FL.BCHH2.10.HD5 absolute= True
# FL.BCHH2.10.HD6 absolute= True
# FL.BCHH2.10.HD7 absolute= True
# FL.BCHH2.10.HD8 absolute= True
# FL.BCHH2.10.HD9 absolute= True
# FL.S39A2.00.HHE absolute= True
# FL.S39A2.00.HHN absolute= True
# FL.S39A2.00.HHZ absolute= True
# FL.S39A2.10.HDF absolute= True
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD4_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD5_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD6_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD7_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD8_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD9_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHE_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHN_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHZ_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.10.HDF_2022.csv
# ('KSC', '2022-04-01T06:00:00', '2022-04-01T07:00:00', None, 1, 0, 0, 0, 1)
# KSC_2022-04-01T06:00:00_2022-04-01T07:00:00 unlocked
# ('KSC', '2022-04-01T06:00:00', '2022-04-01T07:00:00', None, 1, 0, 0, 0, 0)
# KSC_2022-04-01T06:00:00_2022-04-01T07:00:00 was not locked
#
#
# Time now: 2023-11-08T13:38:47.250189
# Processing 2022-04-01T07:00:00.000000Z
# Inserted new row for KSC_2022-04-01T07:00:00_2022-04-01T08:00:00
# Got a lock on KSC_2022-04-01T07:00:00_2022-04-01T08:00:00
#
#
# Time now: 2023-11-08T13:38:47.977565
# ('KSC', '2022-04-01T07:00:00', '2022-04-01T08:00:00', None, 0, 0, 0, 0, 1)
# Got a lock on KSC_2022-04-01T07:00:00_2022-04-01T08:00:00
# ('KSC', '2022-04-01T07:00:00', '2022-04-01T08:00:00', None, 0, 0, 0, 0, 1)
# FL.BCHH2.10.HD4 absolute= True
# FL.BCHH2.10.HD5 absolute= True
# FL.BCHH2.10.HD6 absolute= True
# FL.BCHH2.10.HD7 absolute= True
# FL.BCHH2.10.HD8 absolute= True
# FL.BCHH2.10.HD9 absolute= True
# FL.S39A2.00.HHE absolute= True
# FL.S39A2.00.HHN absolute= True
# FL.S39A2.00.HHZ absolute= True
# FL.S39A2.10.HDF absolute= True
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD4_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD5_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD6_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD7_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD8_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD9_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHE_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHN_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHZ_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.10.HDF_2022.csv
# ('KSC', '2022-04-01T07:00:00', '2022-04-01T08:00:00', None, 1, 0, 0, 0, 1)
# KSC_2022-04-01T07:00:00_2022-04-01T08:00:00 unlocked
# ('KSC', '2022-04-01T07:00:00', '2022-04-01T08:00:00', None, 1, 0, 0, 0, 0)
# KSC_2022-04-01T07:00:00_2022-04-01T08:00:00 was not locked
#
#
# Time now: 2023-11-08T13:38:49.392545
# Processing 2022-04-01T08:00:00.000000Z
# Inserted new row for KSC_2022-04-01T08:00:00_2022-04-01T09:00:00
# Got a lock on KSC_2022-04-01T08:00:00_2022-04-01T09:00:00
#
#
# Time now: 2023-11-08T13:38:50.010545
# ('KSC', '2022-04-01T08:00:00', '2022-04-01T09:00:00', None, 0, 0, 0, 0, 1)
# Got a lock on KSC_2022-04-01T08:00:00_2022-04-01T09:00:00
# ('KSC', '2022-04-01T08:00:00', '2022-04-01T09:00:00', None, 0, 0, 0, 0, 1)
# FL.BCHH2.10.HD4 absolute= True
# FL.BCHH2.10.HD5 absolute= True
# FL.BCHH2.10.HD6 absolute= True
# FL.BCHH2.10.HD7 absolute= True
# FL.BCHH2.10.HD8 absolute= True
# FL.BCHH2.10.HD9 absolute= True
# FL.S39A2.00.HHE absolute= True
# FL.S39A2.00.HHN absolute= True
# FL.S39A2.00.HHZ absolute= True
# FL.S39A2.10.HDF absolute= True
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD4_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD5_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD6_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD7_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD8_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD9_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHE_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHN_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHZ_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.10.HDF_2022.csv
# ('KSC', '2022-04-01T08:00:00', '2022-04-01T09:00:00', None, 1, 0, 0, 0, 1)
# KSC_2022-04-01T08:00:00_2022-04-01T09:00:00 unlocked
# ('KSC', '2022-04-01T08:00:00', '2022-04-01T09:00:00', None, 1, 0, 0, 0, 0)
# KSC_2022-04-01T08:00:00_2022-04-01T09:00:00 was not locked
#
#
# Time now: 2023-11-08T13:38:51.409771
# Processing 2022-04-01T09:00:00.000000Z
# Inserted new row for KSC_2022-04-01T09:00:00_2022-04-01T10:00:00
# Got a lock on KSC_2022-04-01T09:00:00_2022-04-01T10:00:00
#
#
# Time now: 2023-11-08T13:38:52.011779
# ('KSC', '2022-04-01T09:00:00', '2022-04-01T10:00:00', None, 0, 0, 0, 0, 1)
# Got a lock on KSC_2022-04-01T09:00:00_2022-04-01T10:00:00
# ('KSC', '2022-04-01T09:00:00', '2022-04-01T10:00:00', None, 0, 0, 0, 0, 1)
# FL.BCHH2.10.HD4 absolute= True
# FL.BCHH2.10.HD5 absolute= True
# FL.BCHH2.10.HD6 absolute= True
# FL.BCHH2.10.HD7 absolute= True
# FL.BCHH2.10.HD8 absolute= True
# FL.BCHH2.10.HD9 absolute= True
# FL.S39A2.00.HHE absolute= True
# FL.S39A2.00.HHN absolute= True
# FL.S39A2.00.HHZ absolute= True
# FL.S39A2.10.HDF absolute= True
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD4_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD5_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD6_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD7_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD8_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD9_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHE_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHN_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHZ_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.10.HDF_2022.csv
# ('KSC', '2022-04-01T09:00:00', '2022-04-01T10:00:00', None, 1, 0, 0, 0, 1)
# KSC_2022-04-01T09:00:00_2022-04-01T10:00:00 unlocked
# ('KSC', '2022-04-01T09:00:00', '2022-04-01T10:00:00', None, 1, 0, 0, 0, 0)
# KSC_2022-04-01T09:00:00_2022-04-01T10:00:00 was not locked
#
#
# Time now: 2023-11-08T13:38:53.449855
# Processing 2022-04-01T10:00:00.000000Z
# Inserted new row for KSC_2022-04-01T10:00:00_2022-04-01T11:00:00
# Got a lock on KSC_2022-04-01T10:00:00_2022-04-01T11:00:00
#
#
# Time now: 2023-11-08T13:38:54.128252
# ('KSC', '2022-04-01T10:00:00', '2022-04-01T11:00:00', None, 0, 0, 0, 0, 1)
# Got a lock on KSC_2022-04-01T10:00:00_2022-04-01T11:00:00
# ('KSC', '2022-04-01T10:00:00', '2022-04-01T11:00:00', None, 0, 0, 0, 0, 1)
# FL.BCHH2.10.HD4 absolute= True
# FL.BCHH2.10.HD5 absolute= True
# FL.BCHH2.10.HD6 absolute= True
# FL.BCHH2.10.HD7 absolute= True
# FL.BCHH2.10.HD8 absolute= True
# FL.BCHH2.10.HD9 absolute= True
# FL.S39A2.00.HHE absolute= True
# FL.S39A2.00.HHN absolute= True
# FL.S39A2.00.HHZ absolute= True
# FL.S39A2.10.HDF absolute= True
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD4_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD5_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD6_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD7_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD8_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD9_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHE_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHN_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHZ_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.10.HDF_2022.csv
# ('KSC', '2022-04-01T10:00:00', '2022-04-01T11:00:00', None, 1, 0, 0, 0, 1)
# KSC_2022-04-01T10:00:00_2022-04-01T11:00:00 unlocked
# ('KSC', '2022-04-01T10:00:00', '2022-04-01T11:00:00', None, 1, 0, 0, 0, 0)
# KSC_2022-04-01T10:00:00_2022-04-01T11:00:00 was not locked
#
#
# Time now: 2023-11-08T13:38:55.584558
# Processing 2022-04-01T11:00:00.000000Z
# Inserted new row for KSC_2022-04-01T11:00:00_2022-04-01T12:00:00
# Got a lock on KSC_2022-04-01T11:00:00_2022-04-01T12:00:00
#
#
# Time now: 2023-11-08T13:38:56.300788
# ('KSC', '2022-04-01T11:00:00', '2022-04-01T12:00:00', None, 0, 0, 0, 0, 1)
# Got a lock on KSC_2022-04-01
00:00', None, 1, 0, 0, 0, 1)
# KSC_2022-04-18T23:00:00_2022-04-19T00:00:00 unlocked
# ('KSC', '2022-04-18T23:00:00', '2022-04-19T00:00:00', None, 1, 0, 0, 0, 0)
# KSC_2022-04-18T23:00:00_2022-04-19T00:00:00 was not locked
#
#
# Time now: 2023-11-08T14:19:08.643790
# Processing 2022-04-19T00:00:00.000000Z
# Inserted new row for KSC_2022-04-19T00:00:00_2022-04-19T01:00:00
# Got a lock on KSC_2022-04-19T00:00:00_2022-04-19T01:00:00
#
#
# Time now: 2023-11-08T14:19:10.356789
# ('KSC', '2022-04-19T00:00:00', '2022-04-19T01:00:00', None, 0, 0, 0, 0, 1)
# Got a lock on KSC_2022-04-19T00:00:00_2022-04-19T01:00:00
# ('KSC', '2022-04-19T00:00:00', '2022-04-19T01:00:00', None, 0, 0, 0, 0, 1)
# FL.BCHH2.10.HD4 absolute= True
# FL.BCHH2.10.HD5 absolute= True
# FL.BCHH2.10.HD6 absolute= True
# FL.BCHH2.10.HD7 absolute= True
# FL.BCHH2.10.HD8 absolute= True
# FL.BCHH2.10.HD9 absolute= True
# FL.S39A1.00.HHE absolute= True
# FL.S39A1.00.HHN absolute= True
# FL.S39A1.00.HHZ absolute= True
# FL.S39A1.10.HDF absolute= True
# FL.S39A2.00.HHE absolute= True
# FL.S39A2.00.HHN absolute= True
# FL.S39A2.00.HHZ absolute= True
# FL.S39A2.10.HDF absolute= True
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD4_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD5_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD6_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD7_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD8_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD9_2022.csv
# Saving to .\RSAM_metrics_FL.S39A1.00.HHE_2022.csv
# Saving to .\RSAM_metrics_FL.S39A1.00.HHN_2022.csv
# Saving to .\RSAM_metrics_FL.S39A1.00.HHZ_2022.csv
# Saving to .\RSAM_metrics_FL.S39A1.10.HDF_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHE_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHN_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHZ_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.10.HDF_2022.csv
# ('KSC', '2022-04-19T00:00:00', '2022-04-19T01:00:00', None, 1, 0, 0, 0, 1)
# KSC_2022-04-19T00:00:00_2022-04-19T01:00:00 unlocked
# ('KSC', '2022-04-19T00:00:00', '2022-04-19T01:00:00', None, 1, 0, 0, 0, 0)
# KSC_2022-04-19T00:00:00_2022-04-19T01:00:00 was not locked
#
#
# Time now: 2023-11-08T14:19:18.554252
# Processing 2022-04-19T01:00:00.000000Z
# Inserted new row for KSC_2022-04-19T01:00:00_2022-04-19T02:00:00
# Got a lock on KSC_2022-04-19T01:00:00_2022-04-19T02:00:00
#
#
# Time now: 2023-11-08T14:19:19.597252
# ('KSC', '2022-04-19T01:00:00', '2022-04-19T02:00:00', None, 0, 0, 0, 0, 1)
# Got a lock on KSC_2022-04-19T01:00:00_2022-04-19T02:00:00
# ('KSC', '2022-04-19T01:00:00', '2022-04-19T02:00:00', None, 0, 0, 0, 0, 1)
# FL.BCHH2.10.HD4 absolute= True
# FL.BCHH2.10.HD5 absolute= True
# FL.BCHH2.10.HD6 absolute= True
# FL.BCHH2.10.HD7 absolute= True
# FL.BCHH2.10.HD8 absolute= True
# FL.BCHH2.10.HD9 absolute= True
# FL.S39A1.00.HHE absolute= True
# FL.S39A1.00.HHN absolute= True
# FL.S39A1.00.HHZ absolute= True
# FL.S39A1.10.HDF absolute= True
# FL.S39A2.00.HHE absolute= True
# FL.S39A2.00.HHN absolute= True
# FL.S39A2.00.HHZ absolute= True
# FL.S39A2.10.HDF absolute= True
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD4_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD5_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD6_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD7_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD8_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD9_2022.csv
# Saving to .\RSAM_metrics_FL.S39A1.00.HHE_2022.csv
# Saving to .\RSAM_metrics_FL.S39A1.00.HHN_2022.csv
# Saving to .\RSAM_metrics_FL.S39A1.00.HHZ_2022.csv
# Saving to .\RSAM_metrics_FL.S39A1.10.HDF_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHE_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHN_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHZ_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.10.HDF_2022.csv
# ('KSC', '2022-04-19T01:00:00', '2022-04-19T02:00:00', None, 1, 0, 0, 0, 1)
# KSC_2022-04-19T01:00:00_2022-04-19T02:00:00 unlocked
# ('KSC', '2022-04-19T01:00:00', '2022-04-19T02:00:00', None, 1, 0, 0, 0, 0)
# KSC_2022-04-19T01:00:00_2022-04-19T02:00:00 was not locked
#
#
# Time now: 2023-11-08T14:19:27.857193
# Processing 2022-04-19T02:00:00.000000Z
# Inserted new row for KSC_2022-04-19T02:00:00_2022-04-19T03:00:00
# Got a lock on KSC_2022-04-19T02:00:00_2022-04-19T03:00:00
#
#
# Time now: 2023-11-08T14:19:29.089190
# ('KSC', '2022-04-19T02:00:00', '2022-04-19T03:00:00', None, 0, 0, 0, 0, 1)
# Got a lock on KSC_2022-04-19T02:00:00_2022-04-19T03:00:00
# ('KSC', '2022-04-19T02:00:00', '2022-04-19T03:00:00', None, 0, 0, 0, 0, 1)
# FL.BCHH2.10.HD4 absolute= True
# FL.BCHH2.10.HD5 absolute= True
# FL.BCHH2.10.HD6 absolute= True
# FL.BCHH2.10.HD7 absolute= True
# FL.BCHH2.10.HD8 absolute= True
# FL.BCHH2.10.HD9 absolute= True
# FL.S39A1.00.HHE absolute= True
# FL.S39A1.00.HHN absolute= True
# FL.S39A1.00.HHZ absolute= True
# FL.S39A1.10.HDF absolute= True
# FL.S39A2.00.HHE absolute= True
# FL.S39A2.00.HHN absolute= True
# FL.S39A2.00.HHZ absolute= True
# FL.S39A2.10.HDF absolute= True
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD4_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD5_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD6_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD7_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD8_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD9_2022.csv
# Saving to .\RSAM_metrics_FL.S39A1.00.HHE_2022.csv
# Saving to .\RSAM_metrics_FL.S39A1.00.HHN_2022.csv
# Saving to .\RSAM_metrics_FL.S39A1.00.HHZ_2022.csv
# Saving to .\RSAM_metrics_FL.S39A1.10.HDF_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHE_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHN_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHZ_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.10.HDF_2022.csv
# ('KSC', '2022-04-19T02:00:00', '2022-04-19T03:00:00', None, 1, 0, 0, 0, 1)
# KSC_2022-04-19T02:00:00_2022-04-19T03:00:00 unlocked
# ('KSC', '2022-04-19T02:00:00', '2022-04-19T03:00:00', None, 1, 0, 0, 0, 0)
# KSC_2022-04-19T02:00:00_2022-04-19T03:00:00 was not locked
#
#
# Time now: 2023-11-08T14:19:36.973191
# Processing 2022-04-19T03:00:00.000000Z
# Inserted new row for KSC_2022-04-19T03:00:00_2022-04-19T04:00:00
# Got a lock on KSC_2022-04-19T03:00:00_2022-04-19T04:00:00
#
#
# Time now: 2023-11-08T14:19:37.936251
# ('KSC', '2022-04-19T03:00:00', '2022-04-19T04:00:00', None, 0, 0, 0, 0, 1)
# Got a lock on KSC_2022-04-19T03:00:00_2022-04-19T04:00:00
# ('KSC', '2022-04-19T03:00:00', '2022-04-19T04:00:00', None, 0, 0, 0, 0, 1)
# FL.BCHH2.10.HD4 absolute= True
# FL.BCHH2.10.HD5 absolute= True
# FL.BCHH2.10.HD6 absolute= True
# FL.BCHH2.10.HD7 absolute= True
# FL.BCHH2.10.HD8 absolute= True
# FL.BCHH2.10.HD9 absolute= True
# FL.S39A1.00.HHE absolute= True
# FL.S39A1.00.HHN absolute= True
# FL.S39A1.00.HHZ absolute= True
# FL.S39A1.10.HDF absolute= True
# FL.S39A2.00.HHE absolute= True
# FL.S39A2.00.HHN absolute= True
# FL.S39A2.00.HHZ absolute= True
# FL.S39A2.10.HDF absolute= True
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD4_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD5_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD6_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD7_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD8_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD9_2022.csv
# Saving to .\RSAM_metrics_FL.S39A1.00.HHE_2022.csv
# Saving to .\RSAM_metrics_FL.S39A1.00.HHN_2022.csv
# Saving to .\RSAM_metrics_FL.S39A1.00.HHZ_2022.csv
# Saving to .\RSAM_metrics_FL.S39A1.10.HDF_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHE_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHN_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHZ_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.10.HDF_2022.csv
# ('KSC', '2022-04-19T03:00:00', '2022-04-19T04:00:00', None, 1, 0, 0, 0, 1)
# KSC_2022-04-19T03:00:00_2022-04-19T04:00:00 unlocked
# ('KSC', '2022-04-19T03:00:00', '2022-04-19T04:00:00', None, 1, 0, 0, 0, 0)
# KSC_2022-04-19T03:00:00_2022-04-19T04:00:00 was not locked
#
#
# Time now: 2023-11-08T14:19:47.205801
# Processing 2022-04-19T04:00:00.000000Z
# Inserted new row for KSC_2022-04-19T04:00:00_2022-04-19T05:00:00
# Got a lock on KSC_2022-04-19T04:00:00_2022-04-19T05:00:00
#
#
# Time now: 2023-11-08T14:19:48.544799
# ('KSC', '2022-04-19T04:00:00', '2022-04-19T05:00:00', None, 0, 0, 0, 0, 1)
# Got a lock on KSC_2022-04-19T04:00:00_2022-04-19T05:00:00
# ('KSC', '2022-04-19T04:00:00', '2022-04-19T05:00:00', None, 0, 0, 0, 0, 1)
# FL.BCHH2.10.HD4 absolute= True
# FL.BCHH2.10.HD5 absolute= True
# FL.BCHH2.10.HD6 absolute= True
# FL.BCHH2.10.HD7 absolute= True
# FL.BCHH2.10.HD8 absolute= True
# FL.BCHH2.10.HD9 absolute= True
# FL.S39A1.00.HHE absolute= True
# FL.S39A1.00.HHN absolute= True
# FL.S39A1.00.HHZ absolute= True
# FL.S39A1.10.HDF absolute= True
# FL.S39A2.00.HHE absolute= True
# FL.S39A2.00.HHN absolute= True
# FL.S39A2.00.HHZ absolute= True
# FL.S39A2.10.HDF absolute= True
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD4_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD5_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD6_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD7_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD8_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD9_2022.csv
# Saving to .\RSAM_metrics_FL.S39A1.00.HHE_2022.csv
# Saving to .\RSAM_metrics_FL.S39A1.00.HHN_2022.csv
# Saving to .\RSAM_metrics_FL.S39A1.00.HHZ_2022.csv
# Saving to .\RSAM_metrics_FL.S39A1.10.HDF_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHE_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHN_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHZ_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.10.HDF_2022.csv
# ('KSC', '2022-04-19T04:00:00', '2022-04-19T05:00:00', None, 1, 0, 0, 0, 1)
# KSC_2022-04-19T04:00:00_2022-04-19T05:00:00 unlocked
# ('KSC', '2022-04-19T04:00:00', '2022-04-19T05:00:00', None, 1, 0, 0, 0, 0)
# KSC_2022-04-19T04:00:00_2022-04-19T05:00:00 was not locked
#
#
# Time now: 2023-11-08T14:19:57.405333
# Processing 2022-04-19T05:00:00.000000Z
# Inserted new row for KSC_2022-04-19T05:00:00_2022-04-19T06:00:00
# Got a lock on KSC_2022-04-19T05:00:00_2022-04-19T06:00:00
#
#
# Time now: 2023-11-08T14:19:58.540332
# ('KSC', '2022-04-19T05:00:00', '2022-04-19T06:00:00', None, 0, 0, 0, 0, 1)
# Got a lock on KSC_2022-04-19T05:00:00_2022-04-19T06:00:00
# ('KSC', '2022-04-19T05:00:00', '2022-04-19T06:00:00', None, 0, 0, 0, 0, 1)
# FL.BCHH2.10.HD4 absolute= True
# FL.BCHH2.10.HD5 absolute= True
# FL.BCHH2.10.HD6 absolute= True
# FL.BCHH2.10.HD7 absolute= True
# FL.BCHH2.10.HD8 absolute= True
# FL.BCHH2.10.HD9 absolute= True
# FL.S39A1.00.HHE absolute= True
# FL.S39A1.00.HHN absolute= True
# FL.S39A1.00.HHZ absolute= True
# FL.S39A1.10.HDF absolute= True
# FL.S39A2.00.HHE absolute= True
# FL.S39A2.00.HHN absolute= True
# FL.S39A2.00.HHZ absolute= True
# FL.S39A2.10.HDF absolute= True
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD4_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD5_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD6_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD7_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD8_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD9_2022.csv
# Saving to .\RSAM_metrics_FL.S39A1.00.HHE_2022.csv
# Saving to .\RSAM_metrics_FL.S39A1.00.HHN_2022.csv
# Saving to .\RSAM_metrics_FL.S39A1.00.HHZ_2022.csv
# Saving to .\RSAM_metrics_FL.S39A1.10.HDF_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHE_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHN_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHZ_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.10.HDF_2022.csv
# ('KSC', '2022-04-19T05:00:00', '2022-04-19T06:00:00', None, 1, 0, 0, 0, 1)
# KSC_2022-04-19T05:00:00_2022-04-19T06:00:00 unlocked
# ('KSC', '2022-04-19T05:00:00', '2022-04-19T06:00:00', None, 1, 0, 0, 0, 0)
# KSC_2022-04-19T05:00:00_2022-04-19T06:00:00 was not locked
#
#
# Time now: 2023-11-08T14:20:08.495966
# Processing 2022-04-19T06:00:00.000000Z
# Inserted new row for KSC_2022-04-19T06:00:00_2022-04-19T07:00:00
# Got a lock on KSC_2022-04-19T06:00:00_2022-04-19T07:00:00
#
#
# Time now: 2023-11-08T14:20:09.498966
# ('KSC', '2022-04-19T06:00:00', '2022-04-19T07:00:00', None, 0, 0, 0, 0, 1)
# Got a lock on KSC_2022-04-19T06:00:00_2022-04-19T07:00:00
# ('KSC', '2022-04-19T06:00:00', '2022-04-19T07:00:00', None, 0, 0, 0, 0, 1)
# FL.BCHH2.10.HD4 absolute= True
# FL.BCHH2.10.HD5 absolute= True
# FL.BCHH2.10.HD6 absolute= True
# FL.BCHH2.10.HD7 absolute= True
# FL.BCHH2.10.HD8 absolute= True
# FL.BCHH2.10.HD9 absolute= True
# FL.S39A1.00.HHE absolute= True
# FL.S39A1.00.HHN absolute= True
# FL.S39A1.00.HHZ absolute= True
# FL.S39A1.10.HDF absolute= True
# FL.S39A2.00.HHE absolute= True
# FL.S39A2.00.HHN absolute= True
# FL.S39A2.00.HHZ absolute= True
# FL.S39A2.10.HDF absolute= True
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD4_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD5_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD6_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD7_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD8_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD9_2022.csv
# Saving to .\RSAM_metrics_FL.S39A1.00.HHE_2022.csv
# Saving to .\RSAM_metrics_FL.S39A1.00.HHN_2022.csv
# Saving to .\RSAM_metrics_FL.S39A1.00.HHZ_2022.csv
# Saving to .\RSAM_metrics_FL.S39A1.10.HDF_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHE_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHN_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.00.HHZ_2022.csv
# Saving to .\RSAM_metrics_FL.S39A2.10.HDF_2022.csv
# ('KSC', '2022-04-19T06:00:00', '2022-04-19T07:00:00', None, 1, 0, 0, 0, 1)
# KSC_2022-04-19T06:00:00_2022-04-19T07:00:00 unlocked
# ('KSC', '2022-04-19T06:00:00', '2022-04-19T07:00:00', None, 1, 0, 0, 0, 0)
# KSC_2022-04-19T06:00:00_2022-04-19T07:00:00 was not locked
#
#
# Time now: 2023-11-08T14:20:18.276157
# Processing 2022-04-19T07:00:00.000000Z
# Inserted new row for KSC_2022-04-19T07:00:00_2022-04-19T08:00:00
# Got a lock on KSC_2022-04-19T07:00:00_2022-04-19T08:00:00
#
#
# Time now: 2023-11-08T14:20:19.267156
# ('KSC', '2022-04-19T07:00:00', '2022-04-19T08:00:00', None, 0, 0, 0, 0, 1)
# Got a lock on KSC_2022-04-19T07:00:00_2022-04-19T08:00:00
# ('KSC', '2022-04-19T07:00:00', '2022-04-19T08:00:00', None, 0, 0, 0, 0, 1)
# FL.BCHH2.10.HD4 absolute= True
# FL.BCHH2.10.HD5 absolute= True
# FL.BCHH2.10.HD6 absolute= True
# FL.BCHH2.10.HD7 absolute= True
# FL.BCHH2.10.HD8 absolute= True
# FL.BCHH2.10.HD9 absolute= True
# FL.S39A1.00.HHE absolute= True
# FL.S39A1.00.HHN absolute= True
# FL.S39A1.00.HHZ absolute= True
# FL.S39A1.10.HDF absolute= True
# FL.S39A2.00.HHE absolute= True
# FL.S39A2.00.HHN absolute= True
# FL.S39A2.00.HHZ absolute= True
# FL.S39A2.10.HDF absolute= True
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD4_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD5_2022.csv
# Saving to .\RSAM_metrics_FL.BCHH2.10.HD6_2022.csv
