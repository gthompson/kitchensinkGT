# %%
import obspy
from SAM import RSAM
SAM_DIR = '/data/OVSM/SAM'
startTime = obspy.core.UTCDateTime(2012,4,1)
endTime = obspy.core.UTCDateTime(2012,7,1)
rsamObj = RSAM.read(startTime, endTime, SAM_DIR=SAM_DIR, ext='csv')
rsamObj = rsamObj.select(component='Z')

# %%
rsamObj.plot(metrics='median', ylims=[0, 1000])
# Out:
# METRIC:  median

# %%
rsamObj.plot(metrics='fratio', ylims=[-4, 4])
# Out:
# /data/OVSM/SAM/RSAM_*_2012_60s.csv
# Reading  /data/OVSM/SAM/RSAM_NR.TOCH..HHE_2012_60s.csv
# Reading  /data/OVSM/SAM/RSAM_NR.ALF1..HHN_2012_60s.csv
# Reading  /data/OVSM/SAM/RSAM_NR.TAPI..HHN_2012_60s.csv
# Reading  /data/OVSM/SAM/RSAM_NR.ANIL..HHZ_2012_60s.csv
# Reading  /data/OVSM/SAM/RSAM_NR.ALEJ..HHN_2012_60s.csv
# Reading  /data/OVSM/SAM/RSAM_NR.PIRA..HHN_2012_60s.csv
# Reading  /data/OVSM/SAM/RSAM_NR.ESME..HHE_2012_60s.csv
# Reading  /data/OVSM/SAM/RSAM_NR.LAGU..HHN_2012_60s.csv
# Reading  /data/OVSM/SAM/RSAM_NR.RUB4..HHE_2012_60s.csv
# Reading  /data/OVSM/SAM/RSAM_NR.ALF1..HHE_2012_60s.csv
# Reading  /data/OVSM/SAM/RSAM_NR.RUB4..HHZ_2012_60s.csv
# Reading  /data/OVSM/SAM/RSAM_NR.RUB4..HHN_2012_60s.csv
# Reading  /data/OVSM/SAM/RSAM_NR.TAPI..HHE_2012_60s.csv
# Reading  /data/OVSM/SAM/RSAM_NR.PIRA..HHE_2012_60s.csv
# Reading  /data/OVSM/SAM/RSAM_NR.RREF..HHE_2012_60s.csv
# Reading  /data/OVSM/SAM/RSAM_NR.ALEJ..HHZ_2012_60s.csv
# ...
