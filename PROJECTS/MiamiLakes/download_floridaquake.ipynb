# %%
# imports
import os
import obspy

def km2deg(km):
    deg = km / 111.3
    return deg

def inventory2traceid(inv, chancode=''):
    trace_ids = list()

    for networkObject in inv:
        if chancode:
            networkObject = networkObject.select(channel=chancode)
        stationObjects = networkObject.stations

        for stationObject in stationObjects:
            channelObjects = stationObject.channels
            for channelObject in channelObjects:
                this_trace_id = networkObject.code + '.' + stationObject.code + '.*.' + channelObject.code
                trace_ids.append(this_trace_id)
    
    return trace_ids

# constants
PRE_TRIGGER_SECS = 100
POST_TRIGGER_SECS = 300
LATITUDE = 28.557
LONGITUDE = -78.944
searchRadiusKm = 400
searchRadiusDeg = km2deg(searchRadiusKm)
ORIGIN_TIME = obspy.UTCDateTime(2024,2,8,3,48,7)
PRE_FILT = [0.01, 0.02, 15, 18] # defines a bandpass filter

all_streams = obspy.Stream()
startt = ORIGIN_TIME - PRE_TRIGGER_SECS
endt = ORIGIN_TIME + POST_TRIGGER_SECS
invs = []

from obspy.clients.fdsn import Client
for url in ["data.raspberryshake.org","service.iris.edu"]: 
    print(f'Trying to download data from fdsnws client to {url}')
    try:
        fdsnClient = Client(f'https://{url}') #, debug=True)
    except Exception as e:
        print(e)
        continue
    
    invfile = f'FL.{url}.xml'
    inv = None
    
    if os.path.isfile(invfile):
        print(f'reading inventory from {invfile}')
        inv = obspy.read_inventory(invfile)
    else:
        try:
            print(f'Trying to download an inventory for stations centred on ({LONGITUDE}, {LATITUDE}) radius {searchRadiusDeg}')
            inv = fdsnClient.get_stations( \
                starttime=startt, endtime=endt, \
                latitude="%.4f" % LATITUDE, longitude="%.4f" % LONGITUDE, maxradius="%.1f" % searchRadiusDeg, \
                level="response")
        except Exception as e:
            print(e)
            continue
        if inv:
            inv = inv.remove(network='SY') # get rid of synthetic data that annoying exists on IRIS
            print(f'Saving inventory to {invfile}')
            inv.write(invfile, format = 'stationxml')
    
    if inv:
        invs.append(inv)
        
        # get list of unique trace ids
        trace_ids = inventory2traceid(inv) 
        for trace_id in trace_ids:
            print(f'Processing {trace_id}')
            net, sta, loc, chan = trace_id.split('.')
            
            if not chan[0] in 'LMBJSHE': # only want data 20-250 Hz samplong rate
                print('- ignoring as sampling rate is too low')
                continue
            
            if not chan[1] in 'HD': # only want seismic or infrasound/barometric data
                print('- ignoring as not a seismic, infrasound, or barometric channel')
                continue
                
            print(f'Trying to get waveform(s) matching {net}.{sta}.{loc}.{chan} from {startt} to {endt}')
            try:
                stR = fdsnClient.get_waveforms(net, sta, loc, chan, startt, endt)
            except Exception as e:
                print(e)
                continue
            for tr in stR:
                tr.detrend()
                try:
                    print(f'Correcting {tr.id}')
                    tr.remove_response(inventory=inv, pre_filt=PRE_FILT, output="DISP",
                       water_level=60, plot=False) 
                except Exception as e:
                    print(e)
                    continue
                all_streams.append(tr)


if len(all_streams)>0:
    all_streams.merge()

    # Remove 1 Hz (L) channels if higher sampling rate available
    all_ids = [tr.id for tr in all_streams]
    for tr in all_streams:
        if tr.stats.channel[0]=='L':
            net,sta,loc,chan = tr.id.split('.')
            for band_code in 'MJBSHE':
                id_to_check = '.'.join([net, sta, loc, band_code + chan[1:]])
                if id_to_check in all_ids:
                    all_streams.remove(tr)

    # Save & Plot
    outfile = f'floridaquake.{startt}.mseed'
    print(f'Saving to {outfile}')
    all_streams.write(outfile, format='MSEED')
    all_streams.plot(equal_scale=False)
    
for inv in invs:
    print('Plotting an inventory map...this might take a while...')
    inv.plot(projection='local')
# Out:
# Trying to download data from fdsnws client to data.raspberryshake.org
# No FDSN services could be discovered at 'https://data.raspberryshake.org'. This could be due to a temporary service outage or an invalid FDSN service address.
# Trying to download data from fdsnws client to service.iris.edu
# reading inventory from FL.service.iris.edu.xml
# Processing IU.DWPF.*.BH1
# Trying to get waveform(s) matching IU.DWPF.*.BH1 from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting IU.DWPF.00.BH1
# Correcting IU.DWPF.10.BH1
# Processing IU.DWPF.*.BH2
# Trying to get waveform(s) matching IU.DWPF.*.BH2 from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting IU.DWPF.00.BH2
# Correcting IU.DWPF.10.BH2
# Processing IU.DWPF.*.BHZ
# Trying to get waveform(s) matching IU.DWPF.*.BHZ from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting IU.DWPF.00.BHZ
# Correcting IU.DWPF.10.BHZ
# Processing IU.DWPF.*.HH1
# Trying to get waveform(s) matching IU.DWPF.*.HH1 from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting IU.DWPF.10.HH1
# Processing IU.DWPF.*.HH2
# Trying to get waveform(s) matching IU.DWPF.*.HH2 from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting IU.DWPF.10.HH2
# Processing IU.DWPF.*.HHZ
# Trying to get waveform(s) matching IU.DWPF.*.HHZ from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting IU.DWPF.10.HHZ
# Processing IU.DWPF.*.LH1
# Trying to get waveform(s) matching IU.DWPF.*.LH1 from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting IU.DWPF.00.LH1
# Correcting IU.DWPF.10.LH1
# Processing IU.DWPF.*.LH2
# Trying to get waveform(s) matching IU.DWPF.*.LH2 from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting IU.DWPF.00.LH2
# Correcting IU.DWPF.10.LH2
# Processing IU.DWPF.*.LHZ
# Trying to get waveform(s) matching IU.DWPF.*.LHZ from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting IU.DWPF.00.LHZ
# Correcting IU.DWPF.10.LHZ
# Processing IU.DWPF.*.VH1
# - ignoring as sampling rate is too low
# Processing IU.DWPF.*.VH2
# - ignoring as sampling rate is too low
# Processing IU.DWPF.*.VHZ
# - ignoring as sampling rate is too low
# Processing IU.DWPF.*.VMU
# - ignoring as sampling rate is too low
# Processing IU.DWPF.*.VMV
# - ignoring as sampling rate is too low
# Processing IU.DWPF.*.VMW
# - ignoring as sampling rate is too low
# Processing IU.DWPF.*.BH1
# Trying to get waveform(s) matching IU.DWPF.*.BH1 from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting IU.DWPF.00.BH1
# Correcting IU.DWPF.10.BH1
# Processing IU.DWPF.*.BH2
# Trying to get waveform(s) matching IU.DWPF.*.BH2 from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting IU.DWPF.00.BH2
# Correcting IU.DWPF.10.BH2
# Processing IU.DWPF.*.BHZ
# Trying to get waveform(s) matching IU.DWPF.*.BHZ from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting IU.DWPF.00.BHZ
# Correcting IU.DWPF.10.BHZ
# Processing IU.DWPF.*.HH1
# Trying to get waveform(s) matching IU.DWPF.*.HH1 from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting IU.DWPF.10.HH1
# Processing IU.DWPF.*.HH2
# Trying to get waveform(s) matching IU.DWPF.*.HH2 from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting IU.DWPF.10.HH2
# Processing IU.DWPF.*.HHZ
# Trying to get waveform(s) matching IU.DWPF.*.HHZ from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting IU.DWPF.10.HHZ
# Processing IU.DWPF.*.LH1
# Trying to get waveform(s) matching IU.DWPF.*.LH1 from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting IU.DWPF.00.LH1
# Correcting IU.DWPF.10.LH1
# Processing IU.DWPF.*.LH2
# Trying to get waveform(s) matching IU.DWPF.*.LH2 from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting IU.DWPF.00.LH2
# Correcting IU.DWPF.10.LH2
# Processing IU.DWPF.*.LHZ
# Trying to get waveform(s) matching IU.DWPF.*.LHZ from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting IU.DWPF.00.LHZ
# Correcting IU.DWPF.10.LHZ
# Processing IU.DWPF.*.VH1
# - ignoring as sampling rate is too low
# Processing IU.DWPF.*.VH2
# - ignoring as sampling rate is too low
# Processing IU.DWPF.*.VHZ
# - ignoring as sampling rate is too low
# Processing IU.DWPF.*.VMU
# - ignoring as sampling rate is too low
# Processing IU.DWPF.*.VMV
# - ignoring as sampling rate is too low
# Processing IU.DWPF.*.VMW
# - ignoring as sampling rate is too low
# Processing IU.DWPF.*.HN1
# - ignoring as not a seismic, infrasound, or barometric channel
# Processing IU.DWPF.*.HN2
# - ignoring as not a seismic, infrasound, or barometric channel
# Processing IU.DWPF.*.HNZ
# - ignoring as not a seismic, infrasound, or barometric channel
# Processing IU.DWPF.*.LN1
# - ignoring as not a seismic, infrasound, or barometric channel
# Processing IU.DWPF.*.LN2
# - ignoring as not a seismic, infrasound, or barometric channel
# Processing IU.DWPF.*.LNZ
# - ignoring as not a seismic, infrasound, or barometric channel
# Processing IU.DWPF.*.LDO
# Trying to get waveform(s) matching IU.DWPF.*.LDO from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting IU.DWPF.30.LDO
# Correcting IU.DWPF.31.LDO
# Processing IU.DWPF.*.LDO
# Trying to get waveform(s) matching IU.DWPF.*.LDO from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting IU.DWPF.30.LDO
# Correcting IU.DWPF.31.LDO
# Processing IU.DWPF.*.BDF
# Trying to get waveform(s) matching IU.DWPF.*.BDF from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting IU.DWPF.32.BDF
# Processing IU.DWPF.*.LF1
# - ignoring as not a seismic, infrasound, or barometric channel
# Processing IU.DWPF.*.LF2
# - ignoring as not a seismic, infrasound, or barometric channel
# Processing IU.DWPF.*.LFZ
# - ignoring as not a seismic, infrasound, or barometric channel
# Processing IU.DWPF.*.LDO
# Trying to get waveform(s) matching IU.DWPF.*.LDO from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting IU.DWPF.30.LDO
# Correcting IU.DWPF.31.LDO
# Processing IU.DWPF.*.LIO
# - ignoring as not a seismic, infrasound, or barometric channel
# Processing IU.DWPF.*.LKO
# - ignoring as not a seismic, infrasound, or barometric channel
# Processing IU.DWPF.*.LRH
# - ignoring as not a seismic, infrasound, or barometric channel
# Processing IU.DWPF.*.LRI
# - ignoring as not a seismic, infrasound, or barometric channel
# Processing IU.DWPF.*.LWD
# - ignoring as not a seismic, infrasound, or barometric channel
# Processing IU.DWPF.*.LWS
# - ignoring as not a seismic, infrasound, or barometric channel
# Processing N4.060A.*.HH1
# Trying to get waveform(s) matching N4.060A.*.HH1 from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.060A.00.HH1
# Processing N4.060A.*.HH2
# Trying to get waveform(s) matching N4.060A.*.HH2 from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.060A.00.HH2
# Processing N4.060A.*.HHZ
# Trying to get waveform(s) matching N4.060A.*.HHZ from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.060A.00.HHZ
# Processing N4.060A.*.LH1
# Trying to get waveform(s) matching N4.060A.*.LH1 from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.060A.00.LH1
# Processing N4.060A.*.LH2
# Trying to get waveform(s) matching N4.060A.*.LH2 from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.060A.00.LH2
# Processing N4.060A.*.LHZ
# Trying to get waveform(s) matching N4.060A.*.LHZ from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.060A.00.LHZ
# Processing N4.060A.*.VH1
# - ignoring as sampling rate is too low
# Processing N4.060A.*.VH2
# - ignoring as sampling rate is too low
# Processing N4.060A.*.VHZ
# - ignoring as sampling rate is too low
# Processing N4.060A.*.VMU
# - ignoring as sampling rate is too low
# Processing N4.060A.*.VMV
# - ignoring as sampling rate is too low
# Processing N4.060A.*.VMW
# - ignoring as sampling rate is too low
# Processing N4.060A.*.LDO
# Trying to get waveform(s) matching N4.060A.*.LDO from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.060A.30.LDO
# PolynomialResponseStage not yet implemented. Please contact the developers.
# Correcting N4.060A.31.LDO
# PolynomialResponseStage not yet implemented. Please contact the developers.
# Processing N4.060A.*.LDO
# Trying to get waveform(s) matching N4.060A.*.LDO from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.060A.30.LDO
# PolynomialResponseStage not yet implemented. Please contact the developers.
# Correcting N4.060A.31.LDO
# PolynomialResponseStage not yet implemented. Please contact the developers.
# Processing N4.060A.*.BDF
# Trying to get waveform(s) matching N4.060A.*.BDF from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.060A.32.BDF
# Processing N4.061Z.*.HH1
# Trying to get waveform(s) matching N4.061Z.*.HH1 from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.061Z.00.HH1
# Processing N4.061Z.*.HH2
# Trying to get waveform(s) matching N4.061Z.*.HH2 from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.061Z.00.HH2
# Processing N4.061Z.*.HHZ
# Trying to get waveform(s) matching N4.061Z.*.HHZ from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.061Z.00.HHZ
# Processing N4.061Z.*.LH1
# Trying to get waveform(s) matching N4.061Z.*.LH1 from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.061Z.00.LH1
# Processing N4.061Z.*.LH2
# Trying to get waveform(s) matching N4.061Z.*.LH2 from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.061Z.00.LH2
# Processing N4.061Z.*.LHZ
# Trying to get waveform(s) matching N4.061Z.*.LHZ from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.061Z.00.LHZ
# Processing N4.061Z.*.VH1
# - ignoring as sampling rate is too low
# Processing N4.061Z.*.VH2
# - ignoring as sampling rate is too low
# Processing N4.061Z.*.VHZ
# - ignoring as sampling rate is too low
# Processing N4.061Z.*.VMU
# - ignoring as sampling rate is too low
# Processing N4.061Z.*.VMV
# - ignoring as sampling rate is too low
# Processing N4.061Z.*.VMW
# - ignoring as sampling rate is too low
# Processing N4.061Z.*.LDO
# Trying to get waveform(s) matching N4.061Z.*.LDO from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.061Z.30.LDO
# PolynomialResponseStage not yet implemented. Please contact the developers.
# Correcting N4.061Z.31.LDO
# PolynomialResponseStage not yet implemented. Please contact the developers.
# Processing N4.061Z.*.LDO
# Trying to get waveform(s) matching N4.061Z.*.LDO from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.061Z.30.LDO
# PolynomialResponseStage not yet implemented. Please contact the developers.
# Correcting N4.061Z.31.LDO
# PolynomialResponseStage not yet implemented. Please contact the developers.
# Processing N4.061Z.*.BDF
# Trying to get waveform(s) matching N4.061Z.*.BDF from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.061Z.32.BDF
# Processing N4.456A.*.HH1
# Trying to get waveform(s) matching N4.456A.*.HH1 from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.456A.00.HH1
# Processing N4.456A.*.HH2
# Trying to get waveform(s) matching N4.456A.*.HH2 from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.456A.00.HH2
# Processing N4.456A.*.HHZ
# Trying to get waveform(s) matching N4.456A.*.HHZ from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.456A.00.HHZ
# Processing N4.456A.*.LH1
# Trying to get waveform(s) matching N4.456A.*.LH1 from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.456A.00.LH1
# Processing N4.456A.*.LH2
# Trying to get waveform(s) matching N4.456A.*.LH2 from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.456A.00.LH2
# Processing N4.456A.*.LHZ
# Trying to get waveform(s) matching N4.456A.*.LHZ from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.456A.00.LHZ
# Processing N4.456A.*.VH1
# - ignoring as sampling rate is too low
# Processing N4.456A.*.VH2
# - ignoring as sampling rate is too low
# Processing N4.456A.*.VHZ
# - ignoring as sampling rate is too low
# Processing N4.456A.*.VMU
# - ignoring as sampling rate is too low
# Processing N4.456A.*.VMV
# - ignoring as sampling rate is too low
# Processing N4.456A.*.VMW
# - ignoring as sampling rate is too low
# Processing N4.456A.*.LDO
# Trying to get waveform(s) matching N4.456A.*.LDO from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.456A.30.LDO
# PolynomialResponseStage not yet implemented. Please contact the developers.
# Correcting N4.456A.31.LDO
# PolynomialResponseStage not yet implemented. Please contact the developers.
# Processing N4.456A.*.LDO
# Trying to get waveform(s) matching N4.456A.*.LDO from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.456A.30.LDO
# PolynomialResponseStage not yet implemented. Please contact the developers.
# Correcting N4.456A.31.LDO
# PolynomialResponseStage not yet implemented. Please contact the developers.
# Processing N4.456A.*.BDF
# Trying to get waveform(s) matching N4.456A.*.BDF from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.456A.32.BDF
# Processing N4.656A.*.HH1
# Trying to get waveform(s) matching N4.656A.*.HH1 from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.656A.00.HH1
# Processing N4.656A.*.HH2
# Trying to get waveform(s) matching N4.656A.*.HH2 from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.656A.00.HH2
# Processing N4.656A.*.HHZ
# Trying to get waveform(s) matching N4.656A.*.HHZ from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.656A.00.HHZ
# Processing N4.656A.*.LH1
# Trying to get waveform(s) matching N4.656A.*.LH1 from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.656A.00.LH1
# Processing N4.656A.*.LH2
# Trying to get waveform(s) matching N4.656A.*.LH2 from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.656A.00.LH2
# Processing N4.656A.*.LHZ
# Trying to get waveform(s) matching N4.656A.*.LHZ from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.656A.00.LHZ
# Processing N4.656A.*.VH1
# - ignoring as sampling rate is too low
# Processing N4.656A.*.VH2
# - ignoring as sampling rate is too low
# Processing N4.656A.*.VHZ
# - ignoring as sampling rate is too low
# Processing N4.656A.*.VMU
# - ignoring as sampling rate is too low
# Processing N4.656A.*.VMV
# - ignoring as sampling rate is too low
# Processing N4.656A.*.VMW
# - ignoring as sampling rate is too low
# Processing N4.656A.*.LDO
# Trying to get waveform(s) matching N4.656A.*.LDO from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.656A.30.LDO
# PolynomialResponseStage not yet implemented. Please contact the developers.
# Correcting N4.656A.31.LDO
# PolynomialResponseStage not yet implemented. Please contact the developers.
# Processing N4.656A.*.LDO
# Trying to get waveform(s) matching N4.656A.*.LDO from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.656A.30.LDO
# PolynomialResponseStage not yet implemented. Please contact the developers.
# Correcting N4.656A.31.LDO
# PolynomialResponseStage not yet implemented. Please contact the developers.
# Processing N4.656A.*.BDF
# Trying to get waveform(s) matching N4.656A.*.BDF from 2024-02-08T03:46:27.000000Z to 2024-02-08T03:53:07.000000Z
# Correcting N4.656A.32.BDF
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 116
#     114             id_to_check = '.'.join([net, sta, loc, band_code + chan[1:]])
#     115             if id_to_check in all_ids:
# --> 116                 all_streams.remove(tr)
#     118 # Save & Plot
#     119 outfile = f'floridaquake.{startt}.mseed'
#
# File ~/miniconda3/envs/skience24/lib/python3.11/site-packages/obspy/core/stream.py:1311, in Stream.remove(self, trace)
#    1285 def remove(self, trace):
#    1286     """
#    1287     Remove the first occurrence of the specified Trace object in the
#    1288     Stream object. Passes on the remove() call to self.traces.
#    (...)
#    1309     BW.RJOB..EHN | 2009-08-24T00:20:03.000000Z ... | 100.0 Hz, 3000 samples
#    1310     """
# -> 1311     self.traces.remove(trace)
#    1312     return self
#
# ValueError: list.remove(x): x not in list
